# %%
from typing import Set
# Python imports, put at the top for simplicity
from logaut import ltl2dfa
from pylogics.parsers import parse_ltl
import pylogics.parsers.ldl
import logaut

from mdp_dp_rl.algorithms.dp.dp_analytic import DPAnalytic
from stochastic_service_composition.declare_utils import *
from stochastic_service_composition.dfa_target import from_symbolic_automaton_to_declare_automaton
from stochastic_service_composition.dfa_target import mdp_from_dfa
from docs.notebooks.utils import render_service, render_composition_mdp, render_mdp_dfa, \
    print_policy_data, print_value_function, print_q_value_function
from stochastic_service_composition.composition_mdp import comp_mdp
from stochastic_service_composition.services import build_service_from_transitions, Service
from stochastic_service_composition.target import build_target_from_transitions, target_from_dfa

# %% [markdown]
# ## Use case for "Stochastic Service Composition with Industrial APIs" - Chip Production.
#
# In this notebook, we present the implementation of the use case for "Stochastic Service Composition with Industrial APIs" about chip production.

# %% [markdown]
# # Available Services
#
# In the following we provide definitions about available services:

# %%
LOW_PROB = 0.05

# probabilities of being broken after an action
DEFAULT_BROKEN_PROB = LOW_PROB
BROKEN_PROB = 0.5
HIGH_BROKEN_PROB = 0.7

# default probability of being unemployable after the configuration
DEFAULT_UNEMPLOYABLE_PROB = LOW_PROB
HIGH_UNEMPLOYABLE_PROB = 0.5

# costs of the machines that perform their job in different countries
#DEFAULT_USA_REWARD = -1.0
WAR_REWARD = -3.0
USA_REWARD = -1.0
HIGH_USA_REWARD = -5.0
UK_REWARD = -6.8
CHINA_REWARD = -11.7
TAIWAN_REWARD = -12.2
RUSSIA_REWARD = -9.12 # we have to take into the account political problems
NORWAY_REWARD = -7.16
AUSTRALIA_REWARD = -14.0
INDIA_REWARD = -13.1
BELGIUM_REWARD = -7.6
SWITZERLAND_REWARD = -8.0
CANADA_REWARD = -1.8
PERU_REWARD = -6.0
AUSTRIA_REWARD = -8.38
BRAZIL_REWARD = -6.7
FRANCE_REWARD = -7.6
MALAYSIA_REWARD = -14.73
TURKEY_REWARD = -10.16
KAZAKHSTAN_REWARD = -10.4
CHILE_REWARD = -7.8
BOLIVIA_REWARD = -6.8
ARGENTINA_REWARD = -8.55
MOROCCO_REWARD = -7.9
JAPAN_REWARD = -10.1
SOUTH_KOREA = -10.7
NETHERLANDS_REWARD = -7.5

# default reward when the service becomes broken
DEFAULT_BROKEN_REWARD = -10.0

# %%
# all the atomic actions for the task
PICK_BUY_DESIGN = "pick_buy_design"
PICK_SILICON = "pick_silicon"
PICK_WAFER = "pick_wafer"
PICK_BORON = "pick_boron"
PICK_PHOSPHOR = "pick_phosphor"
PICK_ALUMINUM = "pick_aluminum"
PICK_RESIST = "pick_resist"
PICK_PLASTIC = "pick_plastic"
PICK_CHEMICALS = "pick_chemicals"
PICK_COPPER_FRAME = "pick_copper_frame"
CLEANING = "cleaning"
CONFIG_FILM_DEPOSITION = "config_film_deposition"
CHECKED_FILM_DEPOSITION = "checked_film_deposition"
FILM_DEPOSITION = "film_deposition"
CONFIG_RESIST_COATING = "config_resist_coating"
CHECKED_RESIST_COATING = "checked_resist_coating"
RESIST_COATING = "resist_coating"
EXPOSURE = "exposure"
CHECK_EXPOSURE = "check_exposure"
CONFIG_DEVELOPMENT = "config_development"
CHECKED_DEVELOPMENT = "checked_development"
DEVELOPMENT = "development"
ETCHING = "etching"
CHECK_ETCHING = "check_etching"
CONFIG_IMPURITIES_IMPLANTATION = "config_impurities_implantation"
CHECKED_IMPURITIES_IMPLANTATION = "checked_impurities_implantation"
IMPURITIES_IMPLANTATION = "impurities_implantation"
ACTIVATION = "activation"
RESIST_STRIPPING = "resist_stripping"
CHECK_RESIST_STRIPPING = "check_resist_stripping"
ASSEMBLY = "assembly"
TESTING ="testing"
PACKAGING = "packaging"

SYMBOLS_PHASE_1 = [
    PICK_BUY_DESIGN,
    PICK_SILICON,
    PICK_WAFER,
    PICK_BORON,
    PICK_PHOSPHOR,
    PICK_ALUMINUM,
    PICK_RESIST,
    PICK_PLASTIC,
    PICK_CHEMICALS,
    PICK_COPPER_FRAME
]

SYMBOLS_PHASE_2 = [
    CLEANING,
    FILM_DEPOSITION,
    RESIST_COATING,
    EXPOSURE,
    DEVELOPMENT,
    ETCHING,
    IMPURITIES_IMPLANTATION,
    ACTIVATION,
    RESIST_STRIPPING,
    ASSEMBLY,
    TESTING,
    PACKAGING
]

# %%
# service names
DESIGN_SERVICE_NAME_USA = "design_usa"                                      # human
DESIGN_SERVICE_NAME_UK = "design_uk"                                        # human
DESIGN_SERVICE_NAME_CHINA = "design_china"                                  # human
DESIGN_SERVICE_NAME_TAIWAN = "design_taiwan"                                # human
SILICON_SERVICE_NAME_CHINA = "silicon_china"                                # warehouse
SILICON_SERVICE_NAME_RUSSIA = "silicon_russia"                              # warehouse
SILICON_SERVICE_NAME_NORWAY = "silicon_norway"                              # warehouse
SILICON_SERVICE_NAME_USA = "silicon_usa"                                    # warehouse
SILICON_SERVICE_NAME_FRANCE = "silicon_france"                              # warehouse
SILICON_SERVICE_NAME_BRAZIL = "silicon_brazil"                              # warehouse
SILICON_SERVICE_NAME_MALAYSIA = "silicon_malaysia"                          # warehouse
WAFER_SERVICE_NAME_JAPAN = "wafer_japan"                                    # warehouse
WAFER_SERVICE_NAME_SOUTH_KOREA = "wafer_south_korea"                        # warehouse
BORON_SERVICE_NAME_TURKEY = "boron_turkey"                                  # warehouse
BORON_SERVICE_NAME_USA = "boron_usa"                                        # warehouse
BORON_SERVICE_NAME_KAZAKHSTAN = "boron_kazakhstan"                          # warehouse
BORON_SERVICE_NAME_CHILE = "boron_chile"                                    # warehouse
BORON_SERVICE_NAME_CHINA = "boron_china"                                    # warehouse
BORON_SERVICE_NAME_ARGENTINA = "boron_argentina"                            # warehouse
BORON_SERVICE_NAME_RUSSIA = "boron_russia"                                  # warehouse
BORON_SERVICE_NAME_BOLIVIA = "boron_bolivia"                                # warehouse
PHOSPHOR_SERVICE_NAME_MOROCCO = "phosphor_morocco"                          # warehouse
PHOSPHOR_SERVICE_NAME_CHINA = "phosphor_china"                              # warehouse
PHOSPHOR_SERVICE_NAME_USA = "phosphor_usa"                                  # warehouse
ALUMINUM_SERVICE_NAME_AUSTRALIA = "aluminum_australia"                      # warehouse
ALUMINUM_SERVICE_NAME_INDIA = "aluminum_india"                              # warehouse
ALUMINUM_SERVICE_NAME_BRAZIL = "aluminum_brazil"                            # warehouse
RESIST_SERVICE_NAME_USA = "resist_usa"                                      # warehouse
RESIST_SERVICE_NAME_BELGIUM = "resist_belgium"                              # warehouse
RESIST_SERVICE_NAME_AUSTRIA = "resist_austria"                              # warehouse
RESIST_SERVICE_NAME_INDIA = "resist_india"                                  # warehouse
RESIST_SERVICE_NAME_SWITZERLAND = "resist_switzerland"                      # warehouse
RESIST_SERVICE_NAME_CANADA = "resist_canada"                                # warehouse
PLASTIC_SERVICE_NAME_CHINA = "plastic_china"                                # warehouse
PLASTIC_SERVICE_NAME_INDIA = "plastic_india"                                # warehouse
CHEMICALS_SERVICE_NAME_USA = "chemicals_usa"                                # warehouse
CHEMICALS_SERVICE_NAME_CANADA = "chemicals_canada"                          # warehouse
COPPER_FRAME_SERVICE_NAME_USA = "copper_frame_usa"                          # warehouse
COPPER_FRAME_SERVICE_NAME_CHINA = "copper_frame_china"                      # warehouse
COPPER_FRAME_SERVICE_NAME_PERU = "copper_frame_peru"                        # warehouse
COPPER_FRAME_SERVICE_NAME_CHILE = "copper_frame_chile"                      # warehouse
CLEANING_SERVICE_NAME = "cleaning_human"                                    # human
FILM_DEPOSITION1_SERVICE_NAME = "film_deposition_machine1"                  # machine
FILM_DEPOSITION2_SERVICE_NAME = "film_deposition_machine2"                  # machine
RESIST_COATING1_SERVICE_NAME = "resist_coating_machine1"                    # machine
RESIST_COATING2_SERVICE_NAME = "resist_coating_machine2"                    # machine
EXPOSURE_SERVICE_NAME = "exposure_machine"                                  # machine
DEVELOPMENT1_SERVICE_NAME = "development1_machine"                          # machine
DEVELOPMENT2_SERVICE_NAME = "development2_machine"                          # machine
ETCHING1_SERVICE_NAME = "etching1_machine"                                  # machine
ETCHING2_SERVICE_NAME = "etching2_machine"                                  # machine
IMPURITIES_IMPLANTATION_SERVICE_NAME = "impurities_implantation_machine"    # machine
ACTIVATION_SERVICE_NAME = "activation_human"                                # human
RESIST_STRIPPING_SERVICE_NAME = "resist_stripping_machine"                  # machine
ASSEMBLY_SERVICE_NAME = "assembly_human"                                    # human
TESTING_SERVICE_NAME = "testing_human"                                      # human
PACKAGING_SERVICE_NAME = "packaging_human"                                  # human

# %% [markdown]
# We have different type of services:
#
# - generic breakable machines;
# - complex breakable machines;
# - warehouse machines;
# - human workers

# %%
def build_generic_breakable_service(service_name: str, action_name: str, broken_prob: float, broken_reward: float, action_reward: float):
    assert 0.0 <= broken_prob <= 1.0
    deterministic_prob = 1.0
    success_prob = deterministic_prob - broken_prob
    transitions = {
        "available": {
          action_name: ({"done": success_prob, "broken": broken_prob}, action_reward),
        },
        "broken": {
            f"check_{action_name}": ({"available": 1.0}, broken_reward),
        },
        "done": {
            f"check_{action_name}": ({"available": 1.0}, 0.0),
        }
    }
    final_states = {"available"}
    initial_state = "available"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

def build_complex_breakable_service(service_name: str, action_name: str, broken_prob: float, unemployable_prob: float, broken_reward: float, action_reward: float) -> Service:
    assert 0.0 <= broken_prob <= 1.0
    deterministic_prob = 1.0
    configure_success_prob = deterministic_prob - unemployable_prob
    op_success_prob = deterministic_prob - broken_prob
    transitions = {
        "ready": { # current state
            f"config_{action_name}": # action
                (
                    {
                        "configured": deterministic_prob # next state : prob
                    },
                    0.0
                ),
        },
        "configured": {
            f"checked_{action_name}":
                (
                    {
                    "executing": configure_success_prob,
                    "broken": unemployable_prob
                    } if unemployable_prob > 0.0 else {"executing": configure_success_prob},
                    0.0
                ),
        },
        "executing": {
            action_name: # operation
                (
                    {
                        "ready": op_success_prob,
                        "broken": broken_prob
                    } if broken_prob > 0.0 else {"ready": op_success_prob},
                    action_reward
                ),
        },
        "broken": {
            f"restore_{action_name}":
               (
                   {
                       "repairing": deterministic_prob
                   },
                   broken_reward
               ),
        },
        "repairing": {
            f"repaired_{action_name}":
                (
                    {
                        "ready": deterministic_prob
                    },
                    0.0
                ),
        },

    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

def build_generic_service_one_state(
    service_name: str,
    operation_names: Set[str],
    action_reward: float,
) -> Service:
    """Build the one state device."""
    transitions = {
        "ready": {
            operation_name: ({"ready": 1.0}, action_reward) for operation_name in operation_names
        },
    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

# %%
def design_service(name: str, action_reward: float) -> Service:
    """Build the design device."""
    return build_generic_service_one_state(
        name,
        {PICK_BUY_DESIGN},
        action_reward=action_reward
    )

service_design_usa = design_service(DESIGN_SERVICE_NAME_USA, USA_REWARD)
service_design_uk = design_service(DESIGN_SERVICE_NAME_UK, UK_REWARD)
service_design_china = design_service(DESIGN_SERVICE_NAME_CHINA, CHINA_REWARD)
service_design_taiwan = design_service(DESIGN_SERVICE_NAME_TAIWAN, TAIWAN_REWARD)
render_service(service_design_usa)
render_service(service_design_uk)
render_service(service_design_china)
render_service(service_design_taiwan)

# %%
def silicon_warehouse_service(name: str, action_reward) -> Service:
    """Build the silicon warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_SILICON},
        action_reward=action_reward
    )

service_silicon_china = silicon_warehouse_service(SILICON_SERVICE_NAME_CHINA, CHINA_REWARD)
service_silicon_russia = silicon_warehouse_service(SILICON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD)
service_silicon_norway = silicon_warehouse_service(SILICON_SERVICE_NAME_NORWAY, NORWAY_REWARD)
service_silicon_usa = silicon_warehouse_service(SILICON_SERVICE_NAME_USA, USA_REWARD)
service_silicon_brazil = silicon_warehouse_service(SILICON_SERVICE_NAME_BRAZIL, BRAZIL_REWARD)
service_silicon_france = silicon_warehouse_service(SILICON_SERVICE_NAME_FRANCE, FRANCE_REWARD)
service_silicon_malaysia = silicon_warehouse_service(SILICON_SERVICE_NAME_MALAYSIA, MALAYSIA_REWARD)
render_service(service_silicon_china)
render_service(service_silicon_russia)
render_service(service_silicon_norway)
render_service(service_silicon_usa)
render_service(service_silicon_brazil)
render_service(service_silicon_france)
render_service(service_silicon_malaysia)

# %%
def wafer_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the wafer warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_WAFER},
        action_reward=action_reward
    )

service_wafer_japan = wafer_warehouse_service(WAFER_SERVICE_NAME_JAPAN, JAPAN_REWARD)
service_wafer_south_korea = wafer_warehouse_service(WAFER_SERVICE_NAME_SOUTH_KOREA, SOUTH_KOREA)
render_service(service_wafer_japan)
render_service(service_wafer_south_korea)

# %%
def boron_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the boron warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_BORON},
        action_reward=action_reward
    )

service_boron_turkey = boron_warehouse_service(BORON_SERVICE_NAME_TURKEY, TURKEY_REWARD)
service_boron_usa = boron_warehouse_service(BORON_SERVICE_NAME_USA, USA_REWARD)
service_boron_kazakhstan = boron_warehouse_service(BORON_SERVICE_NAME_KAZAKHSTAN, KAZAKHSTAN_REWARD)
service_boron_chile = boron_warehouse_service(BORON_SERVICE_NAME_CHILE, CHILE_REWARD)
service_boron_china = boron_warehouse_service(BORON_SERVICE_NAME_CHINA, CHINA_REWARD)
service_boron_bolivia = boron_warehouse_service(BORON_SERVICE_NAME_BOLIVIA, BOLIVIA_REWARD)
service_boron_argentina = boron_warehouse_service(BORON_SERVICE_NAME_ARGENTINA, ARGENTINA_REWARD)
service_boron_russia = boron_warehouse_service(BORON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD)
render_service(service_boron_turkey)
render_service(service_boron_usa)
render_service(service_boron_kazakhstan)
render_service(service_boron_chile)
render_service(service_boron_china)
render_service(service_boron_bolivia)
render_service(service_boron_argentina)
render_service(service_boron_russia)

# %%
def phosphor_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the phosphor warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_PHOSPHOR},
        action_reward=action_reward
    )

service_phosphor_morocco = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_MOROCCO, MOROCCO_REWARD)
service_phosphor_china = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_CHINA, CHINA_REWARD)
service_phosphor_usa = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_USA, USA_REWARD)
render_service(service_phosphor_morocco)
render_service(service_phosphor_china)
render_service(service_phosphor_usa)

# %%
def aluminum_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the aluminum warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_ALUMINUM},
        action_reward=action_reward
    )

service_aluminum_australia = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_AUSTRALIA, AUSTRALIA_REWARD)
service_aluminum_india = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_INDIA, INDIA_REWARD)
service_aluminum_brazil = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_BRAZIL, BRAZIL_REWARD)
render_service(service_aluminum_australia)
render_service(service_aluminum_india)
render_service(service_aluminum_brazil)

# %%
def resist_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the resist warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_RESIST},
        action_reward=action_reward
    )


service_resist_usa = resist_warehouse_service(RESIST_SERVICE_NAME_USA, USA_REWARD)
service_resist_belgium = resist_warehouse_service(RESIST_SERVICE_NAME_BELGIUM, BELGIUM_REWARD)
service_resist_austria = resist_warehouse_service(RESIST_SERVICE_NAME_AUSTRIA, AUSTRIA_REWARD)
service_resist_india = resist_warehouse_service(RESIST_SERVICE_NAME_INDIA, INDIA_REWARD)
service_resist_switzerland = resist_warehouse_service(RESIST_SERVICE_NAME_SWITZERLAND, SWITZERLAND_REWARD)
service_resist_canada = resist_warehouse_service(RESIST_SERVICE_NAME_CANADA, CANADA_REWARD)
render_service(service_resist_usa)
render_service(service_resist_belgium)
render_service(service_resist_austria)
render_service(service_resist_india)
render_service(service_resist_switzerland)
render_service(service_resist_canada)

# %%
def plastic_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the plastic warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_PLASTIC},
        action_reward=action_reward
    )


service_plastic_china = plastic_warehouse_service(PLASTIC_SERVICE_NAME_CHINA, CHINA_REWARD)
service_plastic_india = plastic_warehouse_service(PLASTIC_SERVICE_NAME_INDIA, INDIA_REWARD)
render_service(service_plastic_china)
render_service(service_plastic_india)

# %%
def chemicals_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the chemicals warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_CHEMICALS},
        action_reward=action_reward
    )


service_chemicals_usa = chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_USA, USA_REWARD)
service_chemicals_canada = chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_CANADA, CANADA_REWARD)
render_service(service_chemicals_usa)
render_service(service_chemicals_canada)

# %%
def copper_frame_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the copper frame warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_COPPER_FRAME},
        action_reward=action_reward
    )


service_copper_frame_usa = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_USA, USA_REWARD)
service_copper_frame_china = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHINA, CHINA_REWARD)
service_copper_frame_peru = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_PERU, PERU_REWARD)
service_copper_frame_chile = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHILE, CHILE_REWARD)
render_service(service_copper_frame_usa)
render_service(service_copper_frame_china)
render_service(service_copper_frame_peru)
render_service(service_copper_frame_chile)

# %%
def cleaning_service(name: str = CLEANING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human cleaning device."""
    return build_generic_service_one_state(
        name,
        {CLEANING},
        action_reward=action_reward
    )


service_cleaning = cleaning_service()
render_service(service_cleaning)

# %%
def film_deposition_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                            action_reward: float) -> Service:
    """Build the film deposition device."""
    return build_complex_breakable_service(name, FILM_DEPOSITION, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_film_deposition1 = film_deposition_service(FILM_DEPOSITION1_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                   DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD)
service_film_deposition2 = film_deposition_service(FILM_DEPOSITION2_SERVICE_NAME, BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_film_deposition1)
render_service(service_film_deposition2)

# %%
def resist_coating_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                           action_reward: float) -> Service:
    """Build the resist coating device."""
    return build_complex_breakable_service(name, RESIST_COATING, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_resist_coating1 = resist_coating_service(RESIST_COATING1_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                 DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD)
service_resist_coating2 = resist_coating_service(RESIST_COATING2_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                 DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_resist_coating1)
render_service(service_resist_coating2)

# %%
def exposure_service(name: str = EXPOSURE_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB,
                     broken_reward: float = DEFAULT_BROKEN_REWARD,
                     action_reward: float = USA_REWARD) -> Service:
    """Build the exposure device."""
    return build_generic_breakable_service(name, EXPOSURE, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_exposure = exposure_service()
render_service(service_exposure)

# %%
def development_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                        action_reward: float) -> Service:
    """Build the development device."""
    return build_complex_breakable_service(name, DEVELOPMENT, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_development1 = development_service(DEVELOPMENT1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB,
                                           DEFAULT_BROKEN_REWARD, USA_REWARD)
service_development2 = development_service(DEVELOPMENT2_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_development1)
render_service(service_development2)

# %%
def etching_service(name: str, broken_prob: float, broken_reward: float, action_reward: float) -> Service:
    """Build the etching device."""
    return build_generic_breakable_service(name, ETCHING, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_etching1 = etching_service(ETCHING1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_BROKEN_REWARD,
                                   USA_REWARD)
service_etching2 = etching_service(ETCHING2_SERVICE_NAME, BROKEN_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_etching1)
render_service(service_etching2)

# %%
def impurities_implantation_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                                    action_reward: float) -> Service:
    """Build the impurities implantation device."""
    return build_complex_breakable_service(name, IMPURITIES_IMPLANTATION, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_impurities_implantation = impurities_implantation_service(IMPURITIES_IMPLANTATION_SERVICE_NAME,
                                                                   DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB,
                                                                   DEFAULT_BROKEN_REWARD, USA_REWARD)
render_service(service_impurities_implantation)

# %%
def activation_service(name: str = ACTIVATION_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human activation device."""
    return build_generic_service_one_state(
        name,
        {ACTIVATION},
        action_reward=action_reward
    )


service_activation = activation_service()
render_service(service_activation)

# %%
def resist_stripping_service(name: str, broken_prob: float, broken_reward: float, action_reward: float) -> Service:
    """Build the resist stripping device."""
    return build_generic_breakable_service(name, RESIST_STRIPPING, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_resist_stripping = resist_stripping_service(RESIST_STRIPPING_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                     DEFAULT_BROKEN_REWARD, USA_REWARD)
render_service(service_resist_stripping)

# %%
def assembly_service(name: str = ASSEMBLY_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human assembly device."""
    return build_generic_service_one_state(
        name,
        {ASSEMBLY},
        action_reward=action_reward
    )


service_assembly = assembly_service()
render_service(service_assembly)

# %%
def testing_service(name: str = TESTING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human testing device."""
    return build_generic_service_one_state(
        name,
        {TESTING},
        action_reward=action_reward
    )


service_testing = testing_service()
render_service(service_testing)

# %%
def packaging_service(name: str = PACKAGING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human packaging device."""
    return build_generic_service_one_state(
        name,
        {PACKAGING},
        action_reward=action_reward
    )


service_packaging = packaging_service()
render_service(service_packaging)

# %% [markdown]
# # First Phase - Raw materials and design assortment
# ## Target Specification
# The target specification of the first phase is defined as follows:

# %%
constraints = [
    build_declare_assumption(set(SYMBOLS_PHASE_1)),
    *[exactly_once(x) for x in SYMBOLS_PHASE_1],
]

for i in range(len(SYMBOLS_PHASE_1)-1):
    for j in range(i, len(SYMBOLS_PHASE_1)):
        constraints.append(alt_precedence(SYMBOLS_PHASE_1[i], SYMBOLS_PHASE_1[j]))
formula = pylogics.parsers.ltl.parse_ltl(" & ".join(constraints))
automaton = logaut.core.ltl2dfa(formula, backend="lydia")
declare_automaton = from_symbolic_automaton_to_declare_automaton(automaton, set(SYMBOLS_PHASE_1))
render_mdp_dfa(mdp_from_dfa(declare_automaton), no_sink=True)

#formula_str = "<"
#regex_seq = ""
#for symbol_index, symbol in enumerate(SYMBOLS_PHASE_1):
#    all_but_symbol = set(SYMBOLS_PHASE_1).difference({symbol})
#    item = symbol + "&" + " & ".join(map(lambda x: "!" + x, all_but_symbol))
#    regex_seq = regex_seq + (";" if symbol_index != 0 else "") + item
#formula_str = f"<({regex_seq})*>end"
#formula = pylogics.parsers.ldl.parse_ldl(formula_str)
#automaton = logaut.core.ldl2dfa(formula, backend="lydia")
#declare_automaton = from_symbolic_automaton_to_declare_automaton(automaton, set(SYMBOLS_PHASE_1))
#render_mdp_dfa(mdp_from_dfa(declare_automaton), no_sink=True)

# %% [markdown]
# ## Composition MDP
# The Composition MDP is constructed in this way:

# %%
from stochastic_service_composition.rendering import mdp_to_graphviz

all_services = [
    # 0
    design_service(DESIGN_SERVICE_NAME_USA, USA_REWARD),
    # 1
    design_service(DESIGN_SERVICE_NAME_UK, UK_REWARD),
    # 2
    design_service(DESIGN_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 3
    design_service(DESIGN_SERVICE_NAME_TAIWAN, TAIWAN_REWARD),
    # 4
    silicon_warehouse_service(SILICON_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 5
    silicon_warehouse_service(SILICON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD),
    # 6
    silicon_warehouse_service(SILICON_SERVICE_NAME_NORWAY, NORWAY_REWARD),
    # 7
    silicon_warehouse_service(SILICON_SERVICE_NAME_USA, USA_REWARD),
    # 8
    silicon_warehouse_service(SILICON_SERVICE_NAME_BRAZIL, BRAZIL_REWARD),
    # 9
    silicon_warehouse_service(SILICON_SERVICE_NAME_FRANCE, FRANCE_REWARD),
    # 10
    silicon_warehouse_service(SILICON_SERVICE_NAME_MALAYSIA, MALAYSIA_REWARD),
    # 11
    wafer_warehouse_service(WAFER_SERVICE_NAME_JAPAN, JAPAN_REWARD),
    # 12
    wafer_warehouse_service(WAFER_SERVICE_NAME_SOUTH_KOREA, SOUTH_KOREA),
    # 13
    boron_warehouse_service(BORON_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 14
    boron_warehouse_service(BORON_SERVICE_NAME_USA, USA_REWARD),
    # 15
    boron_warehouse_service(BORON_SERVICE_NAME_CHILE, CHILE_REWARD),
    # 16
    boron_warehouse_service(BORON_SERVICE_NAME_KAZAKHSTAN, KAZAKHSTAN_REWARD),
    # 17
    boron_warehouse_service(BORON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD),
    # 18
    boron_warehouse_service(BORON_SERVICE_NAME_ARGENTINA, ARGENTINA_REWARD),
    # 19
    boron_warehouse_service(BORON_SERVICE_NAME_BOLIVIA, BOLIVIA_REWARD),
    # 20
    boron_warehouse_service(BORON_SERVICE_NAME_TURKEY, TURKEY_REWARD),
    # 21
    phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 22
    phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_MOROCCO, MOROCCO_REWARD),
    # 23
    phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_USA, USA_REWARD),
    # 24
    aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_AUSTRALIA, AUSTRALIA_REWARD),
    # 25
    aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_BRAZIL, BRAZIL_REWARD),
    # 26
    aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_INDIA, INDIA_REWARD),
    # 27
    resist_warehouse_service(RESIST_SERVICE_NAME_USA, USA_REWARD),
    # 28
    resist_warehouse_service(RESIST_SERVICE_NAME_SWITZERLAND, SWITZERLAND_REWARD),
    # 29
    resist_warehouse_service(RESIST_SERVICE_NAME_INDIA, INDIA_REWARD),
    # 30
    resist_warehouse_service(RESIST_SERVICE_NAME_CANADA, CANADA_REWARD),
    # 31
    resist_warehouse_service(RESIST_SERVICE_NAME_BELGIUM, BELGIUM_REWARD),
    # 32
    resist_warehouse_service(RESIST_SERVICE_NAME_AUSTRIA, AUSTRIA_REWARD),
    # 33
    plastic_warehouse_service(PLASTIC_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 34
    plastic_warehouse_service(PLASTIC_SERVICE_NAME_INDIA, INDIA_REWARD),
    # 35
    chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_CANADA, CANADA_REWARD),
    # 36
    chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_USA, USA_REWARD),
    # 37
    copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHILE, CHILE_REWARD),
    # 38
    copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHINA, CHINA_REWARD),
    # 39
    copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_PERU, PERU_REWARD),
    # 40
    copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_USA, USA_REWARD)
]
# trimmed_declare_automaton = declare_automaton.trim()
# trimmed_declare_automaton.to_graphviz().render("dfa-trimmed")
# stochastic_target = target_from_dfa(trimmed_declare_automaton)
# mdp = composition_mdp(stochastic_target, *all_services, gamma=0.9)
mdp = comp_mdp(declare_automaton, all_services, gamma=0.9)
render_composition_mdp(mdp)

# %% [markdown]
# # Optimal policy
# Calculation of optimal policy:

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
value_function = opn.get_value_func_dict(opt_policy)
q_value_function = opn.get_act_value_func_dict(opt_policy)

# %%
print_policy_data(opt_policy)
# Out:
# Policy:
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 0),	Action=('pick_buy_design', 0)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 2),	Action=('pick_silicon', 7)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 3),	Action=('pick_wafer', 11)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 4),	Action=('pick_boron', 14)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 5),	Action=('pick_phosphor', 23)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 6),	Action=('pick_aluminum', 25)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 7),	Action=('pick_resist', 27)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 8),	Action=('pick_plastic', 33)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 9),	Action=('pick_chemicals', 36)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 10),	Action=('pick_copper_frame', 40)
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 11),	Action=undefined
# State=-1,	Action=undefined

# %% [markdown]
# # Value Function
# Calculation of Value Function:

# %%
print_value_function(value_function)
# Out:
# Value function:
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 7),	value=-12.34
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 10),	value=0.0
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 0),	value=-21.98036494
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 3),	value=-24.790574
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 9),	value=-1.0
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 6),	value=-17.806
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 2),	value=-23.3115166
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 5),	value=-17.0254
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 8),	value=-12.6
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 4),	value=-16.322860000000002
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 11),	value=0.0
# State=-1,	value=0.0

# %%
print_q_value_function(q_value_function)
# Out:
# Q-value function:
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 0):
# 	Action=('pick_buy_design', 0),	Value=-21.98036494
# 	Action=('pick_buy_design', 1),	Value=-27.780364940000002
# 	Action=('pick_buy_design', 2),	Value=-32.680364940000004
# 	Action=('pick_buy_design', 3),	Value=-33.180364940000004
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 2):
# 	Action=('pick_silicon', 4),	Value=-34.0115166
# 	Action=('pick_silicon', 5),	Value=-34.4315166
# 	Action=('pick_silicon', 6),	Value=-29.4715166
# 	Action=('pick_silicon', 7),	Value=-23.3115166
# 	Action=('pick_silicon', 8),	Value=-29.0115166
# 	Action=('pick_silicon', 9),	Value=-29.9115166
# 	Action=('pick_silicon', 10),	Value=-37.0415166
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 3):
# 	Action=('pick_wafer', 11),	Value=-24.790574
# 	Action=('pick_wafer', 12),	Value=-25.390574
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 4):
# 	Action=('pick_boron', 13),	Value=-27.02286
# 	Action=('pick_boron', 14),	Value=-16.322860000000002
# 	Action=('pick_boron', 15),	Value=-23.122860000000003
# 	Action=('pick_boron', 16),	Value=-25.722860000000004
# 	Action=('pick_boron', 17),	Value=-27.442860000000003
# 	Action=('pick_boron', 18),	Value=-23.872860000000003
# 	Action=('pick_boron', 19),	Value=-22.122860000000003
# 	Action=('pick_boron', 20),	Value=-25.482860000000002
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 5):
# 	Action=('pick_phosphor', 21),	Value=-27.7254
# 	Action=('pick_phosphor', 22),	Value=-23.925400000000003
# 	Action=('pick_phosphor', 23),	Value=-17.0254
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 6):
# 	Action=('pick_aluminum', 24),	Value=-25.106
# 	Action=('pick_aluminum', 25),	Value=-17.806
# 	Action=('pick_aluminum', 26),	Value=-24.206
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 7):
# 	Action=('pick_resist', 27),	Value=-12.34
# 	Action=('pick_resist', 28),	Value=-19.34
# 	Action=('pick_resist', 29),	Value=-24.439999999999998
# 	Action=('pick_resist', 30),	Value=-13.14
# 	Action=('pick_resist', 31),	Value=-18.939999999999998
# 	Action=('pick_resist', 32),	Value=-19.72
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 8):
# 	Action=('pick_plastic', 33),	Value=-12.6
# 	Action=('pick_plastic', 34),	Value=-14.0
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 9):
# 	Action=('pick_chemicals', 35),	Value=-1.8
# 	Action=('pick_chemicals', 36),	Value=-1.0
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 10):
# 	Action=('pick_copper_frame', 37),	Value=-6.8
# 	Action=('pick_copper_frame', 38),	Value=-10.7
# 	Action=('pick_copper_frame', 39),	Value=-5.0
# 	Action=('pick_copper_frame', 40),	Value=0.0
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 11):
# 	Action=undefined,	Value=0.0
#
# State=-1:
# 	Action=undefined,	Value=0.0

# %% [markdown]
# From the calculation of the optimal policy of the raw materials and design assortment phase we observe that:
# - the planner preferred using service `service_design_usa` (service `0`) because it was more convenient choose the service located in the USA than the services of other costly countries;
# - the planner preferred using service `service_silicon_usa` (service `7`) because it was more convenient pick the silicon from the warehouse located in the USA instead of picking it from other costly countries;
# - the planner preferred using service `service_wafer_japan` (service `11`) because it was more convenient pick the wafer from the Japan instead of picking it from South Korea;
# - the planner preferred using service `service_boron_usa` (service `14`) because it was more convenient pick the boron from the warehouse located in the USA instead of picking it from other costly countries;
# - the planner preferred using service `service_phosphor_usa` (service `23`) because it was more convenient pick the phosphor from the warehouse located in the USA instead of picking it from other costly countries;
# - the planner preferred using service `service_aluminum_brazil` (service `25`) because it was more convenient pick the aluminum from the warehouse located in Brazil instead of picking it from other costly countries;
# - the planner preferred using service `service_resist_usa` (service `27`) because it was more convenient pick the resist from the warehouse located in the USA instead of picking it from other costly countries;
# - the planner preferred using service `service_plastic_china` (service `33`) because it was more convenient pick the plastic from the warehouse located in China instead of picking it from India;
# - the planner preferred using service `service_chemicals_usa` (service `36`) because it was more convenient pick the chemicals from the warehouse located in the USA instead of picking it from Canada;
# - the planner preferred using service `service_copper_frame_usa` (service `40`) because it was more convenient pick the copper frame from the warehouse located in the USA instead of picking it from other costly countries.

# %% [markdown]
# # Second phase - Manufacturing Process
# ## Target Specification
# The target specification of the second phase is structured as follows:

# %%
constraints = [
    build_declare_assumption(set(SYMBOLS_PHASE_2)),
    *[exactly_once(x) for x in SYMBOLS_PHASE_2],
]

for i in range(len(SYMBOLS_PHASE_2) - 1):
    for j in range(i, len(SYMBOLS_PHASE_2)):
        constraints.append(alt_precedence(SYMBOLS_PHASE_2[i], SYMBOLS_PHASE_2[j]))
formula = pylogics.parsers.ltl.parse_ltl(" & ".join(constraints))
automaton = logaut.core.ltl2dfa(formula, backend="lydia")
declare_automaton = from_symbolic_automaton_to_declare_automaton(automaton, set(SYMBOLS_PHASE_2))
render_mdp_dfa(mdp_from_dfa(declare_automaton), no_sink=True)

# %%
all_services = [
    # 0
    cleaning_service(CLEANING_SERVICE_NAME, USA_REWARD),
    # 1
    film_deposition_service(FILM_DEPOSITION1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 2
    film_deposition_service(FILM_DEPOSITION2_SERVICE_NAME, BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD),
    # 3
    resist_coating_service(RESIST_COATING1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 4
    resist_coating_service(RESIST_COATING2_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD),
    # 5
    exposure_service(EXPOSURE_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 6
    development_service(DEVELOPMENT1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 7
    development_service(DEVELOPMENT2_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD),
    # 8
    etching_service(ETCHING1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 9
    etching_service(ETCHING2_SERVICE_NAME, BROKEN_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD),
    # 10
    impurities_implantation_service(IMPURITIES_IMPLANTATION_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB,DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 11
    activation_service(ACTIVATION_SERVICE_NAME, USA_REWARD),
    # 12
    resist_stripping_service(RESIST_STRIPPING_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_BROKEN_REWARD, USA_REWARD),
    # 13
    assembly_service(ASSEMBLY_SERVICE_NAME, USA_REWARD),
    # 14
    testing_service(TESTING_SERVICE_NAME, USA_REWARD),
    # 15
    packaging_service(PACKAGING_SERVICE_NAME, USA_REWARD)
]
mdp = comp_mdp(declare_automaton, all_services, gamma=0.9)
#render_composition_mdp(mdp)
print("Number of states: ", len(mdp.all_states))
# Out:
# Number of states:  363

# %% [markdown]
# # Optimal policy
# Calculation of optimal policy:

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
value_function = opn.get_value_func_dict(opt_policy)
q_value_function = opn.get_act_value_func_dict(opt_policy)

# %%
print_policy_data(opt_policy)
# Out:
# Policy:
# State=(('ready', 'ready', 'ready', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'repairing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'configured', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'broken', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'executing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'ready', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'repairing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'broken', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'ready', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'broken', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'executing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'ready', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'configured', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'executing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'repairing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'configured', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'ready', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'repairing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'executing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'ready', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'broken', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'repairing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'executing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'ready', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'broken', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'configured', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'broken', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'ready', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'configured', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'broken', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'executing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'broken', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'repairing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'broken', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'broken', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'repairing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'repairing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'executing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'ready', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'repairing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'executing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'ready', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'repairing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'executing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'ready', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'repairing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'configured', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'broken', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'executing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'configured', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'configured', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'broken', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'configured', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'executing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'configured', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'broken', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'repairing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'broken', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'configured', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'broken', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'configured', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'repairing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'ready', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'broken', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'configured', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'broken', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'executing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'ready', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'executing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'ready', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'repairing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'ready', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'configured', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'executing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'repairing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'ready', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'configured', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'broken', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'configured', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'repairing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'ready', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'ready', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'broken', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'executing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'executing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'configured', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'broken', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'executing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'repairing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'broken', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'configured', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'repairing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'repairing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'configured', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'executing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'configured', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'broken', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'ready', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'configured', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'repairing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'executing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'ready', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'repairing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'executing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'configured', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'broken', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'broken', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'repairing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'executing', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'ready', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'configured', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'repairing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'repairing', 'executing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'broken', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'executing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'ready', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'ready', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'executing', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'ready', 'broken'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'ready', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'repairing', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'broken', 'executing', 'repairing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'configured', 'ready'), 0),	Action=('cleaning', 0)
# State=(('ready', 'executing', 'configured', 'executing'), 0),	Action=('cleaning', 0)
# State=(('ready', 'configured', 'repairing', 'configured'), 0),	Action=('cleaning', 0)
# State=(('ready', 'ready', 'ready', 'ready'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'executing', 'repairing', 'ready'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'configured', 'configured', 'ready'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'broken', 'broken', 'ready'), 2),	Action=('restore_film_deposition', 1)
# State=(('ready', 'configured', 'executing', 'executing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'executing', 'ready', 'configured'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'configured', 'repairing', 'executing'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'configured', 'broken', 'ready'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'repairing', 'ready', 'ready'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'ready', 'broken', 'repairing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'executing', 'ready'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'ready', 'executing'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'configured', 'executing'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'executing', 'executing', 'executing'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'broken', 'repairing', 'ready'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'executing', 'configured', 'ready'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'broken', 'ready', 'configured'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'ready', 'repairing', 'repairing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'configured', 'executing', 'ready'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'ready', 'executing'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'repairing', 'broken', 'configured'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'configured', 'repairing', 'ready'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'executing', 'executing'), 2),	Action=('film_deposition', 2)
# State=(('ready', 'configured', 'ready', 'executing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'repairing', 'broken', 'broken'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'ready', 'configured', 'repairing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'broken', 'repairing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'ready', 'ready'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'configured', 'ready'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'ready', 'broken', 'configured'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'executing', 'executing', 'ready'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'ready', 'broken', 'broken'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'repairing', 'configured'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'ready', 'broken', 'executing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'configured', 'broken', 'repairing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'repairing', 'repairing', 'broken'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'repairing', 'repairing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'executing', 'repairing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'broken', 'ready', 'ready'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'ready', 'repairing', 'configured'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'broken', 'executing', 'ready'), 2),	Action=('film_deposition', 2)
# State=(('ready', 'configured', 'ready', 'ready'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'ready', 'repairing', 'broken'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'ready', 'executing', 'broken'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'ready', 'ready', 'repairing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'ready', 'repairing', 'executing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'configured', 'broken'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'broken', 'broken'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'ready', 'executing', 'repairing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'executing', 'configured', 'repairing'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'repairing', 'configured', 'repairing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'broken', 'repairing'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'ready', 'configured', 'configured'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'configured', 'executing', 'repairing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'ready', 'configured', 'broken'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'broken', 'executing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'repairing', 'broken'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'configured', 'broken', 'configured'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'configured', 'configured', 'broken'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'broken', 'broken'), 2),	Action=('restore_film_deposition', 1)
# State=(('ready', 'broken', 'configured', 'repairing'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'executing', 'repairing', 'repairing'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'repairing', 'ready', 'configured'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'configured', 'broken', 'broken'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'configured', 'configured', 'repairing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'broken', 'repairing'), 2),	Action=('restore_film_deposition', 1)
# State=(('ready', 'repairing', 'executing', 'configured'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'ready', 'broken'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'executing', 'broken'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'ready', 'repairing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'repairing', 'executing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'ready', 'ready', 'configured'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'executing', 'configured', 'configured'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'ready', 'executing', 'configured'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'broken', 'repairing', 'broken'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'ready', 'ready', 'broken'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'configured', 'configured'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'broken', 'configured'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'executing', 'configured', 'broken'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'broken', 'repairing', 'repairing'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'ready', 'ready', 'executing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'configured', 'ready', 'repairing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'repairing', 'broken', 'ready'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'ready', 'executing', 'executing'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'configured', 'executing', 'configured'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'repairing', 'configured', 'executing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'broken', 'executing'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'configured', 'executing', 'broken'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'configured', 'repairing', 'broken'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'ready', 'broken', 'ready'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'broken', 'configured', 'configured'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'configured', 'repairing', 'repairing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'executing', 'repairing', 'configured'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'ready', 'configured', 'executing'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'executing', 'executing', 'configured'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'configured', 'configured', 'configured'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'broken', 'configured'), 2),	Action=('restore_film_deposition', 1)
# State=(('ready', 'executing', 'ready', 'broken'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'configured', 'broken'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'repairing', 'repairing', 'ready'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'executing', 'broken'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'executing', 'ready', 'repairing'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'executing', 'repairing', 'executing'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'executing', 'executing', 'repairing'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'configured', 'configured', 'executing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'broken', 'broken', 'executing'), 2),	Action=('restore_film_deposition', 1)
# State=(('ready', 'configured', 'broken', 'executing'), 2),	Action=('checked_film_deposition', 1)
# State=(('ready', 'ready', 'repairing', 'ready'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'ready', 'executing', 'ready'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'repairing', 'ready', 'executing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'repairing', 'configured', 'ready'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'broken', 'repairing', 'configured'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'repairing', 'executing', 'executing'), 2),	Action=('repaired_film_deposition', 1)
# State=(('ready', 'executing', 'broken', 'ready'), 2),	Action=('film_deposition', 1)
# State=(('ready', 'broken', 'executing', 'configured'), 2),	Action=('film_deposition', 2)
# State=(('ready', 'configured', 'ready', 'configured'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'ready', 'broken'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'executing', 'broken'), 2),	Action=('film_deposition', 2)
# State=(('ready', 'configured', 'ready', 'broken'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'ready', 'repairing'), 2),	Action=('config_film_deposition', 2)
# State=(('ready', 'broken', 'repairing', 'executing'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'broken', 'executing', 'repairing'), 2),	Action=('film_deposition', 2)
# State=(('ready', 'ready', 'configured', 'ready'), 2),	Action=('config_film_deposition', 1)
# State=(('ready', 'executing', 'configured', 'executing'), 2),	Action=('checked_film_deposition', 2)
# State=(('ready', 'configured', 'repairing', 'configured'), 2),	Action=('repaired_film_deposition', 2)
# State=(('ready', 'ready', 'repairing', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'broken', 'repairing', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'configured', 'broken', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'ready', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'ready', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'repairing', 'ready', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'repairing', 'broken', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'ready', 'ready', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'broken', 'ready', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'executing', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'broken', 'executing', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'executing', 'ready', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'executing', 'broken', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'configured', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'broken', 'configured', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'configured', 'broken', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'broken', 'broken', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'ready', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'broken', 'ready', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'ready', 'executing', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'broken', 'executing', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'executing', 'ready', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'executing', 'broken', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'repairing', 'ready', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'repairing', 'broken', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'broken', 'broken', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'ready', 'ready', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'broken', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'broken', 'broken', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'ready', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'ready', 'broken', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'ready', 'configured', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'broken', 'configured', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'broken', 'broken', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'configured', 'broken', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'ready', 'repairing', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'broken', 'repairing', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'repairing', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'broken', 'repairing', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'repairing', 'ready', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'repairing', 'broken', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'repairing', 'ready', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'repairing', 'broken', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'configured', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'configured', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'ready', 'broken', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'broken', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'ready', 'configured', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'broken', 'configured', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'broken', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'configured', 'broken', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'configured', 'broken', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'repairing', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'repairing', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'ready', 'executing', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'executing', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'executing', 'ready', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'executing', 'broken', 'configured'), 3),	Action=('checked_resist_coating', 3)
# State=(('ready', 'broken', 'ready', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'ready', 'executing', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'broken', 'executing', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'executing', 'ready', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'executing', 'broken', 'broken'), 3),	Action=('restore_resist_coating', 3)
# State=(('ready', 'broken', 'ready', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'ready', 'repairing', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'broken', 'repairing', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'executing', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'broken', 'executing', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'executing', 'ready', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'executing', 'broken', 'repairing'), 3),	Action=('repaired_resist_coating', 3)
# State=(('ready', 'ready', 'broken', 'ready'), 3),	Action=('config_resist_coating', 3)
# State=(('ready', 'repairing', 'ready', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'repairing', 'broken', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'ready', 'configured', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'broken', 'configured', 'executing'), 3),	Action=('resist_coating', 3)
# State=(('ready', 'configured', 'ready', 'ready'), 4),	Action=undefined
# State=(('ready', 'configured', 'ready', 'broken'), 4),	Action=undefined
# State=(('ready', 'configured', 'broken', 'ready'), 4),	Action=undefined
# State=(('ready', 'configured', 'broken', 'broken'), 4),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready'), 4),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken'), 4),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready'), 4),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken'), 4),	Action=undefined
# State=(('ready', 'ready', 'executing', 'ready'), 4),	Action=undefined
# State=(('ready', 'ready', 'executing', 'broken'), 4),	Action=undefined
# State=(('ready', 'broken', 'executing', 'ready'), 4),	Action=undefined
# State=(('ready', 'broken', 'executing', 'broken'), 4),	Action=undefined
# State=(('ready', 'executing', 'ready', 'ready'), 4),	Action=undefined
# State=(('ready', 'executing', 'ready', 'broken'), 4),	Action=undefined
# State=(('ready', 'executing', 'broken', 'ready'), 4),	Action=undefined
# State=(('ready', 'executing', 'broken', 'broken'), 4),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready'), 4),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken'), 4),	Action=undefined
# State=(('ready', 'ready', 'broken', 'ready'), 4),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken'), 4),	Action=undefined
# State=(('ready', 'ready', 'repairing', 'ready'), 4),	Action=undefined
# State=(('ready', 'ready', 'repairing', 'broken'), 4),	Action=undefined
# State=(('ready', 'broken', 'repairing', 'ready'), 4),	Action=undefined
# State=(('ready', 'broken', 'repairing', 'broken'), 4),	Action=undefined
# State=(('ready', 'repairing', 'ready', 'ready'), 4),	Action=undefined
# State=(('ready', 'repairing', 'ready', 'broken'), 4),	Action=undefined
# State=(('ready', 'repairing', 'broken', 'ready'), 4),	Action=undefined
# State=(('ready', 'repairing', 'broken', 'broken'), 4),	Action=undefined
# State=(('ready', 'ready', 'configured', 'ready'), 4),	Action=undefined
# State=(('ready', 'ready', 'configured', 'broken'), 4),	Action=undefined
# State=(('ready', 'broken', 'configured', 'ready'), 4),	Action=undefined
# State=(('ready', 'broken', 'configured', 'broken'), 4),	Action=undefined
# State=-1,	Action=undefined

# %% [markdown]
# # Value Function
# Calculation of Value Function:

# %%
print_value_function(value_function)
# Out:
# Value function:
# State=(('ready', 'ready', 'ready', 'ready'), 4),	value=0.0
# State=(('ready', 'ready', 'configured', 'executing'), 0),	value=-1.7971346202472098
# State=(('ready', 'ready', 'executing', 'executing'), 0),	value=-1.8748
# State=(('ready', 'repairing', 'repairing', 'executing'), 2),	value=-0.6456790424002399
# State=(('ready', 'executing', 'executing', 'executing'), 0),	value=-1.9
# State=(('ready', 'configured', 'executing', 'broken'), 2),	value=-9.454733120001652
# State=(('ready', 'broken', 'broken', 'executing'), 2),	value=-10.983612404944195
# State=(('ready', 'broken', 'executing', 'ready'), 4),	value=0.0
# State=(('ready', 'broken', 'repairing', 'executing'), 2),	value=-3.8631026721602155
# State=(('ready', 'executing', 'broken', 'ready'), 4),	value=0.0
# State=(('ready', 'configured', 'configured', 'executing'), 2),	value=-0.984116815120012
# State=(('ready', 'executing', 'configured', 'configured'), 0),	value=-2.1491766913600667
# State=(('ready', 'repairing', 'executing', 'ready'), 0),	value=-2.034579808001489
# State=(('ready', 'executing', 'executing', 'broken'), 2),	value=-10.305259022224059
# State=(('ready', 'configured', 'ready', 'broken'), 0),	value=-7.896888104407959
# State=(('ready', 'broken', 'ready', 'configured'), 0),	value=-5.162934734063821
# State=(('ready', 'ready', 'configured', 'ready'), 0),	value=-2.0441746363557196
# State=(('ready', 'configured', 'ready', 'executing'), 2),	value=-0.8857051336080108
# State=(('ready', 'broken', 'broken', 'ready'), 2),	value=-11.226476375086113
# State=(('ready', 'broken', 'repairing', 'ready'), 2),	value=-4.13295152787346
# State=(('ready', 'ready', 'broken', 'broken'), 2),	value=-8.617597090143574
# State=(('ready', 'ready', 'ready', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'configured', 'configured', 'ready'), 2),	value=-1.2891044893280497
# State=(('ready', 'configured', 'broken', 'executing'), 0),	value=-2.21433630240024
# State=(('ready', 'broken', 'ready', 'repairing'), 2),	value=-4.5621851581134845
# State=(('ready', 'ready', 'repairing', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'executing', 'configured', 'ready'), 2),	value=-1.239176691360067
# State=(('ready', 'repairing', 'broken', 'ready'), 2),	value=-1.3627515278734603
# State=(('ready', 'ready', 'ready', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'executing', 'ready'), 0),	value=-2.1495331200016543
# State=(('ready', 'configured', 'ready', 'broken'), 4),	value=0.0
# State=(('ready', 'executing', 'executing', 'ready'), 0),	value=-2.239176691360067
# State=(('ready', 'executing', 'configured', 'repairing'), 2),	value=-1.2052590222240602
# State=(('ready', 'ready', 'configured', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'broken', 'executing', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'configured', 'ready'), 4),	value=0.0
# State=(('ready', 'executing', 'broken', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'executing', 'executing', 'configured'), 2),	value=-1.4187366560000827
# State=(('ready', 'repairing', 'broken', 'configured'), 0),	value=-2.253461260657439
# State=(('ready', 'ready', 'ready', 'configured'), 0),	value=-1.9644611743309992
# State=(('ready', 'repairing', 'executing', 'executing'), 2),	value=-0.8748
# State=(('ready', 'executing', 'ready', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'broken', 'executing', 'configured'), 0),	value=-5.876862990400074
# State=(('ready', 'configured', 'broken', 'broken'), 2),	value=-9.575107877937304
# State=(('ready', 'repairing', 'repairing', 'ready'), 2),	value=-0.8457814554481333
# State=(('ready', 'ready', 'executing', 'ready'), 4),	value=0.0
# State=(('ready', 'repairing', 'repairing', 'configured'), 0),	value=-1.7812135512081093
# State=(('ready', 'ready', 'ready', 'repairing'), 2),	value=-1.019470634744869
# State=(('ready', 'configured', 'ready', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'configured', 'repairing'), 0),	value=-2.0194706347448688
# State=(('ready', 'ready', 'repairing', 'broken'), 2),	value=-6.207199293967164
# State=(('ready', 'broken', 'ready', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'ready', 'broken', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'configured', 'executing', 'broken'), 0),	value=-9.509259808001488
# State=(('ready', 'ready', 'configured', 'configured'), 2),	value=-1.1906928078160484
# State=(('ready', 'executing', 'ready', 'configured'), 0),	value=-2.0342590222240604
# State=(('ready', 'broken', 'ready', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'configured', 'ready', 'configured'), 0),	value=-2.0716235270344434
# State=(('ready', 'configured', 'ready', 'repairing'), 2),	value=-1.1327451497165213
# State=(('ready', 'broken', 'ready', 'executing'), 0),	value=-4.863102672160216
# State=(('ready', 'configured', 'broken', 'executing'), 3),	value=0.0
# State=(('ready', 'configured', 'repairing', 'configured'), 0),	value=-1.964461174330999
# State=(('ready', 'executing', 'ready', 'repairing'), 2),	value=-1.0847331200016543
# State=(('ready', 'configured', 'repairing', 'repairing'), 2),	value=-1.0194706347448692
# State=(('ready', 'ready', 'broken', 'ready'), 0),	value=-2.3627515278734608
# State=(('ready', 'ready', 'repairing', 'ready'), 0),	value=-1.8457814554481333
# State=(('ready', 'repairing', 'configured', 'configured'), 0),	value=-1.964461174330999
# State=(('ready', 'configured', 'executing', 'executing'), 2),	value=-1.08
# State=(('ready', 'executing', 'ready', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'repairing', 'ready', 'repairing'), 0),	value=-1.825771214143344
# State=(('ready', 'ready', 'broken', 'repairing'), 0),	value=-2.335766642302136
# State=(('ready', 'repairing', 'configured', 'repairing'), 2),	value=-1.019470634744869
# State=(('ready', 'executing', 'broken', 'repairing'), 0),	value=-2.2052590222240602
# State=(('ready', 'repairing', 'ready', 'broken'), 2),	value=-6.207199293967163
# State=(('ready', 'ready', 'repairing', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'broken', 'broken', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'configured', 'ready', 'ready'), 2),	value=-1.1601940403952447
# State=(('ready', 'configured', 'broken', 'configured'), 2),	value=-1.7194255976096553
# State=(('ready', 'ready', 'repairing', 'repairing'), 0),	value=-1.825771214143344
# State=(('ready', 'repairing', 'executing', 'configured'), 0),	value=-2.0620531200016545
# State=(('ready', 'broken', 'ready', 'repairing'), 0),	value=-5.1059666423021355
# State=(('ready', 'broken', 'ready', 'broken'), 2),	value=-11.695597090143576
# State=(('ready', 'configured', 'broken', 'ready'), 0),	value=-2.5141683643038446
# State=(('ready', 'repairing', 'executing', 'repairing'), 2),	value=-1.122059808001489
# State=(('ready', 'broken', 'repairing', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'ready', 'broken', 'ready'), 4),	value=0.0
# State=(('ready', 'ready', 'repairing', 'ready'), 4),	value=0.0
# State=(('ready', 'ready', 'broken', 'configured'), 2),	value=-1.54748303784869
# State=(('ready', 'executing', 'broken', 'configured'), 2),	value=-1.4187366560000827
# State=(('ready', 'executing', 'repairing', 'configured'), 2),	value=-1.0342590222240604
# State=(('ready', 'broken', 'broken', 'broken'), 0),	value=-16.282228278714662
# State=(('ready', 'configured', 'repairing', 'executing'), 0),	value=-1.7174211582224885
# State=(('ready', 'repairing', 'broken', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'broken', 'configured', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'configured', 'broken', 'ready'), 4),	value=0.0
# State=(('ready', 'broken', 'ready', 'ready'), 0),	value=-5.13295152787346
# State=(('ready', 'executing', 'ready', 'broken'), 2),	value=-8.347259808001487
# State=(('ready', 'configured', 'repairing', 'broken'), 2),	value=-6.896888104407959
# State=(('ready', 'executing', 'configured', 'executing'), 2),	value=-0.9
# State=(('ready', 'broken', 'broken', 'configured'), 0),	value=-11.128115134591692
# State=(('ready', 'ready', 'repairing', 'configured'), 2),	value=-0.9644611743309991
# State=(('ready', 'repairing', 'broken', 'broken'), 4),	value=0.0
# State=(('ready', 'broken', 'repairing', 'configured'), 0),	value=-4.746641260657439
# State=(('ready', 'ready', 'executing', 'broken'), 2),	value=-8.509259808001488
# State=(('ready', 'broken', 'broken', 'repairing'), 2),	value=-11.202189978071923
# State=(('ready', 'broken', 'broken', 'broken'), 4),	value=0.0
# State=(('ready', 'configured', 'configured', 'configured'), 0),	value=-2.190692807816048
# State=(('ready', 'repairing', 'ready', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'broken', 'executing'), 3),	value=0.0
# State=(('ready', 'repairing', 'configured', 'broken'), 2),	value=-6.896888104407959
# State=(('ready', 'executing', 'broken', 'broken'), 0),	value=-10.274733120001654
# State=(('ready', 'broken', 'ready', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'configured', 'broken'), 2),	value=-7.663209004897732
# State=(('ready', 'ready', 'executing', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'broken', 'repairing', 'repairing'), 2),	value=-4.1059666423021355
# State=(('ready', 'broken', 'repairing', 'broken'), 4),	value=0.0
# State=(('ready', 'ready', 'ready', 'executing'), 0),	value=-1.7174211582224888
# State=(('ready', 'configured', 'configured', 'repairing'), 2),	value=-1.2586057219072457
# State=(('ready', 'executing', 'ready', 'executing'), 0),	value=-1.729
# State=(('ready', 'ready', 'repairing', 'executing'), 3),	value=0.0
# State=(('ready', 'broken', 'ready', 'ready'), 4),	value=0.0
# State=(('ready', 'executing', 'repairing', 'broken'), 0),	value=-7.761280444481205
# State=(('ready', 'broken', 'configured', 'executing'), 0),	value=-5.29233630240024
# State=(('ready', 'configured', 'executing', 'configured'), 0),	value=-2.311176691360067
# State=(('ready', 'ready', 'broken', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'executing', 'broken', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'configured', 'repairing', 'ready'), 0),	value=-1.9397571727201481
# State=(('ready', 'configured', 'broken', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'repairing', 'ready', 'configured'), 2),	value=-0.9644611743309991
# State=(('ready', 'executing', 'broken', 'broken'), 4),	value=0.0
# State=(('ready', 'ready', 'executing', 'repairing'), 0),	value=-2.122059808001489
# State=(('ready', 'executing', 'executing', 'repairing'), 0),	value=-2.2052590222240602
# State=(('ready', 'broken', 'executing', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'repairing', 'ready', 'ready'), 0),	value=-1.8457814554481333
# State=(('ready', 'configured', 'executing', 'repairing'), 2),	value=-1.3852590222240604
# State=(('ready', 'ready', 'repairing', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'repairing', 'broken', 'repairing'), 2),	value=-1.335766642302136
# State=(('ready', 'repairing', 'repairing', 'repairing'), 2),	value=-0.825771214143344
# State=(('ready', 'broken', 'configured', 'broken'), 2),	value=-12.995107877937304
# State=(('ready', 'configured', 'broken', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'executing', 'broken', 'executing'), 2),	value=-1.0
# State=(('ready', 'repairing', 'broken', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'broken', 'broken', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'broken', 'executing', 'executing'), 2),	value=-5.0
# State=(('ready', 'ready', 'broken', 'executing'), 2),	value=-1.2143363024002398
# State=(('ready', 'ready', 'ready', 'broken'), 0),	value=-7.207199293967163
# State=(('ready', 'broken', 'configured', 'repairing'), 0),	value=-5.5621851581134845
# State=(('ready', 'broken', 'executing', 'broken'), 0),	value=-13.874733120001657
# State=(('ready', 'repairing', 'ready', 'ready'), 4),	value=0.0
# State=(('ready', 'repairing', 'configured', 'executing'), 0),	value=-1.7174211582224885
# State=(('ready', 'broken', 'repairing', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'executing', 'ready', 'ready'), 0),	value=-2.0037331200016544
# State=(('ready', 'ready', 'repairing', 'executing'), 2),	value=-0.7174211582224888
# State=(('ready', 'broken', 'ready', 'ready'), 3),	value=-0.4187366560000828
# State=(('ready', 'executing', 'repairing', 'executing'), 2),	value=-0.729
# State=(('ready', 'broken', 'configured', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'ready', 'ready', 'broken'), 4),	value=0.0
# State=(('ready', 'broken', 'executing', 'repairing'), 2),	value=-5.339176691360066
# State=(('ready', 'broken', 'executing', 'broken'), 4),	value=0.0
# State=(('ready', 'broken', 'configured', 'ready'), 0),	value=-5.592168364303845
# State=(('ready', 'ready', 'configured', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'executing', 'executing'), 3),	value=0.0
# State=(('ready', 'repairing', 'configured', 'ready'), 0),	value=-1.9397571727201481
# State=(('ready', 'executing', 'ready', 'ready'), 4),	value=0.0
# State=(('ready', 'executing', 'configured', 'executing'), 0),	value=-1.81
# State=(('ready', 'repairing', 'broken', 'executing'), 0),	value=-1.983612404944194
# State=(('ready', 'repairing', 'broken', 'broken'), 2),	value=-7.755837381129215
# State=(('ready', 'repairing', 'repairing', 'broken'), 2),	value=-5.586479364570447
# State=(('ready', 'repairing', 'executing', 'broken'), 0),	value=-7.892500444481204
# State=(('ready', 'repairing', 'ready', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'ready', 'ready'), 2),	value=-1.04417463635572
# State=(('ready', 'broken', 'configured', 'ready'), 4),	value=0.0
# State=(('ready', 'configured', 'ready', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'ready', 'configured', 'broken'), 0),	value=-7.896888104407959
# State=(('ready', 'repairing', 'repairing', 'executing'), 0),	value=-1.581111138160216
# State=(('ready', 'broken', 'broken', 'executing'), 0),	value=-10.885251164449775
# State=(('ready', 'broken', 'executing', 'ready'), 2),	value=-5.376862990400074
# State=(('ready', 'broken', 'repairing', 'executing'), 0),	value=-4.476792404944194
# State=(('ready', 'ready', 'configured', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'executing', 'broken', 'ready'), 2),	value=-1.3768629904000744
# State=(('ready', 'configured', 'configured', 'executing'), 0),	value=-1.8857051336080106
# State=(('ready', 'executing', 'repairing', 'ready'), 2),	value=-1.0037331200016544
# State=(('ready', 'broken', 'configured', 'configured'), 2),	value=-5.139425597609655
# State=(('ready', 'repairing', 'ready', 'configured'), 0),	value=-1.8680150568978993
# State=(('ready', 'ready', 'ready', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'broken', 'configured', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'executing', 'executing', 'broken'), 0),	value=-10.274733120001653
# State=(('ready', 'broken', 'executing', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'ready', 'configured', 'executing'), 2),	value=-0.8857051336080108
# State=(('ready', 'ready', 'executing', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'executing', 'executing'), 2),	value=-0.972
# State=(('ready', 'executing', 'executing', 'executing'), 2),	value=-1.0
# State=(('ready', 'configured', 'ready', 'executing'), 0),	value=-1.7971346202472098
# State=(('ready', 'executing', 'broken', 'executing'), 0),	value=-1.9
# State=(('ready', 'broken', 'broken', 'ready'), 0),	value=-11.103828737577503
# State=(('ready', 'broken', 'repairing', 'ready'), 0),	value=-4.719656375086115
# State=(('ready', 'ready', 'broken', 'broken'), 0),	value=-8.755837381129217
# State=(('ready', 'repairing', 'broken', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'configured', 'configured', 'ready'), 0),	value=-2.1601940403952447
# State=(('ready', 'executing', 'configured', 'configured'), 2),	value=-1.2768629904000743
# State=(('ready', 'repairing', 'executing', 'ready'), 2),	value=-1.1495331200016543
# State=(('ready', 'ready', 'ready', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'executing', 'configured', 'ready'), 0),	value=-2.1152590222240604
# State=(('ready', 'repairing', 'broken', 'ready'), 0),	value=-2.226476375086114
# State=(('ready', 'broken', 'executing', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'configured', 'ready', 'broken'), 2),	value=-7.663209004897732
# State=(('ready', 'executing', 'configured', 'repairing'), 0),	value=-2.084733120001654
# State=(('ready', 'broken', 'ready', 'configured'), 2),	value=-4.62548303784869
# State=(('ready', 'ready', 'configured', 'ready'), 2),	value=-1.1601940403952444
# State=(('ready', 'executing', 'executing', 'configured'), 0),	value=-2.2768629904000743
# State=(('ready', 'broken', 'repairing', 'ready'), 4),	value=0.0
# State=(('ready', 'configured', 'broken', 'executing'), 2),	value=-1.3492625582224886
# State=(('ready', 'repairing', 'executing', 'executing'), 0),	value=-1.78732
# State=(('ready', 'ready', 'configured', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'repairing', 'broken', 'ready'), 4),	value=0.0
# State=(('ready', 'configured', 'broken', 'broken'), 0),	value=-9.617597090143573
# State=(('ready', 'repairing', 'repairing', 'ready'), 0),	value=-1.76120330990332
# State=(('ready', 'ready', 'executing', 'ready'), 2),	value=-1.2772590222240603
# State=(('ready', 'executing', 'executing', 'ready'), 2),	value=-1.3768629904000744
# State=(('ready', 'executing', 'ready', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'configured', 'ready', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'ready', 'ready', 'repairing'), 0),	value=-1.9175235712703822
# State=(('ready', 'repairing', 'broken', 'configured'), 2),	value=-1.392734734063821
# State=(('ready', 'ready', 'repairing', 'broken'), 0),	value=-6.586479364570448
# State=(('ready', 'ready', 'ready', 'ready'), 0),	value=-1.9397571727201481
# State=(('ready', 'ready', 'broken', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'configured', 'broken', 'broken'), 4),	value=0.0
# State=(('ready', 'configured', 'executing', 'ready'), 2),	value=-1.4191766913600672
# State=(('ready', 'ready', 'repairing', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'configured', 'configured'), 0),	value=-2.0716235270344434
# State=(('ready', 'repairing', 'ready', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'repairing', 'repairing', 'configured'), 2),	value=-0.8680150568978994
# State=(('ready', 'configured', 'ready', 'repairing'), 0),	value=-2.0194706347448688
# State=(('ready', 'ready', 'configured', 'repairing'), 2),	value=-1.1327451497165213
# State=(('ready', 'executing', 'ready', 'repairing'), 0),	value=-1.9762598080014888
# State=(('ready', 'configured', 'repairing', 'repairing'), 0),	value=-1.9175235712703822
# State=(('ready', 'broken', 'ready', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'configured', 'executing', 'executing'), 0),	value=-1.972
# State=(('ready', 'repairing', 'configured', 'repairing'), 0),	value=-1.9175235712703824
# State=(('ready', 'executing', 'ready', 'configured'), 2),	value=-1.149176691360067
# State=(('ready', 'repairing', 'ready', 'broken'), 0),	value=-6.586479364570447
# State=(('ready', 'configured', 'ready', 'configured'), 2),	value=-1.1906928078160484
# State=(('ready', 'repairing', 'ready', 'executing'), 2),	value=-0.7174211582224888
# State=(('ready', 'configured', 'ready', 'ready'), 0),	value=-2.04417463635572
# State=(('ready', 'broken', 'ready', 'executing'), 2),	value=-4.29233630240024
# State=(('ready', 'configured', 'broken', 'configured'), 0),	value=-2.54748303784869
# State=(('ready', 'configured', 'repairing', 'configured'), 2),	value=-1.0716235270344434
# State=(('ready', 'ready', 'executing', 'configured'), 2),	value=-1.3111766913600669
# State=(('ready', 'broken', 'ready', 'broken'), 0),	value=-11.526037381129218
# State=(('ready', 'repairing', 'executing', 'repairing'), 0),	value=-2.00985382720134
# State=(('ready', 'ready', 'broken', 'ready'), 2),	value=-1.5141683643038446
# State=(('ready', 'configured', 'broken', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'ready', 'repairing', 'ready'), 2),	value=-0.9397571727201481
# State=(('ready', 'ready', 'broken', 'configured'), 0),	value=-2.392734734063821
# State=(('ready', 'repairing', 'configured', 'configured'), 2),	value=-1.0716235270344434
# State=(('ready', 'executing', 'broken', 'configured'), 0),	value=-2.2768629904000743
# State=(('ready', 'repairing', 'ready', 'repairing'), 2),	value=-0.9175235712703822
# State=(('ready', 'executing', 'configured', 'broken'), 2),	value=-9.27473312000165
# State=(('ready', 'ready', 'broken', 'repairing'), 2),	value=-1.4841851581134844
# State=(('ready', 'executing', 'repairing', 'configured'), 0),	value=-1.9308331200016542
# State=(('ready', 'executing', 'broken', 'repairing'), 2),	value=-1.3391766913600671
# State=(('ready', 'broken', 'broken', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'repairing', 'ready', 'broken'), 4),	value=0.0
# State=(('ready', 'broken', 'repairing', 'configured'), 3),	value=-0.4652629511112031
# State=(('ready', 'configured', 'broken', 'repairing'), 2),	value=-1.6490946201260936
# State=(('ready', 'executing', 'broken', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'configured', 'ready', 'ready'), 4),	value=0.0
# State=(('ready', 'ready', 'repairing', 'repairing'), 2),	value=-0.9175235712703822
# State=(('ready', 'executing', 'repairing', 'repairing'), 2),	value=-0.9762598080014889
# State=(('ready', 'repairing', 'executing', 'configured'), 2),	value=-1.1800590222240603
# State=(('ready', 'broken', 'ready', 'broken'), 4),	value=0.0
# State=(('ready', 'configured', 'broken', 'ready'), 2),	value=-1.6824092936709385
# State=(('ready', 'ready', 'ready', 'executing'), 3),	value=0.0
# State=(('ready', 'executing', 'ready', 'executing'), 3),	value=0.0
# State=(('ready', 'executing', 'ready', 'broken'), 0),	value=-8.512533827201338
# State=(('ready', 'configured', 'repairing', 'broken'), 0),	value=-7.207199293967164
# State=(('ready', 'ready', 'repairing', 'configured'), 0),	value=-1.868015056897899
# State=(('ready', 'broken', 'configured', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'executing', 'broken'), 0),	value=-8.658333827201337
# State=(('ready', 'broken', 'broken', 'repairing'), 0),	value=-11.08197098026473
# State=(('ready', 'broken', 'broken', 'broken'), 2),	value=-16.98025364301629
# State=(('ready', 'configured', 'repairing', 'executing'), 2),	value=-0.7971346202472097
# State=(('ready', 'configured', 'ready', 'repairing'), 3),	value=-0.3768629904000744
# State=(('ready', 'repairing', 'configured', 'broken'), 0),	value=-7.207199293967164
# State=(('ready', 'ready', 'executing', 'repairing'), 3),	value=-0.3768629904000745
# State=(('ready', 'broken', 'repairing', 'repairing'), 0),	value=-4.695369978071923
# State=(('ready', 'broken', 'repairing', 'broken'), 2),	value=-10.526037381129218
# State=(('ready', 'configured', 'configured', 'repairing'), 0),	value=-2.1327451497165213
# State=(('ready', 'configured', 'executing', 'ready'), 0),	value=-2.2772590222240603
# State=(('ready', 'configured', 'configured', 'broken'), 2),	value=-8.514676672108592
# State=(('ready', 'broken', 'ready', 'ready'), 2),	value=-4.592168364303845
# State=(('ready', 'executing', 'ready', 'broken'), 4),	value=0.0
# State=(('ready', 'broken', 'broken', 'configured'), 2),	value=-11.253461260657437
# State=(('ready', 'repairing', 'ready', 'broken'), 3),	value=-10.339176691360068
# State=(('ready', 'broken', 'repairing', 'configured'), 2),	value=-4.162934734063821
# State=(('ready', 'ready', 'executing', 'broken'), 4),	value=0.0
# State=(('ready', 'configured', 'configured', 'configured'), 2),	value=-1.3229920086844982
# State=(('ready', 'executing', 'broken', 'broken'), 2),	value=-10.305259022224059
# State=(('ready', 'configured', 'broken', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'configured', 'executing', 'repairing'), 0),	value=-2.2467331200016543
# State=(('ready', 'ready', 'configured', 'broken'), 4),	value=0.0
# State=(('ready', 'repairing', 'broken', 'repairing'), 0),	value=-2.2021899780719223
# State=(('ready', 'repairing', 'repairing', 'repairing'), 0),	value=-1.7431940927290097
# State=(('ready', 'broken', 'configured', 'broken'), 0),	value=-12.695597090143576
# State=(('ready', 'ready', 'ready', 'executing'), 2),	value=-0.7971346202472097
# State=(('ready', 'executing', 'ready', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'executing', 'ready', 'executing'), 2),	value=-0.8099999999999999
# State=(('ready', 'executing', 'broken', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'executing', 'repairing', 'broken'), 2),	value=-7.512533827201339
# State=(('ready', 'broken', 'configured', 'executing'), 2),	value=-4.769262558222489
# State=(('ready', 'configured', 'executing', 'configured'), 2),	value=-1.4568629904000745
# State=(('ready', 'broken', 'executing', 'executing'), 0),	value=-5.5
# State=(('ready', 'configured', 'repairing', 'ready'), 2),	value=-1.04417463635572
# State=(('ready', 'repairing', 'ready', 'executing'), 0),	value=-1.6456790424002399
# State=(('ready', 'ready', 'broken', 'executing'), 0),	value=-2.092902672160216
# State=(('ready', 'ready', 'executing', 'repairing'), 2),	value=-1.2467331200016543
# State=(('ready', 'executing', 'executing', 'repairing'), 2),	value=-1.3391766913600671
# State=(('ready', 'repairing', 'ready', 'ready'), 2),	value=-0.9397571727201481
# State=(('ready', 'broken', 'configured', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'executing', 'configured'), 0),	value=-2.1800590222240603
# State=(('ready', 'broken', 'configured', 'broken'), 4),	value=0.0
# State=(('ready', 'ready', 'repairing', 'executing'), 0),	value=-1.6456790424002399
# State=(('ready', 'broken', 'broken', 'ready'), 4),	value=0.0
# State=(('ready', 'executing', 'repairing', 'executing'), 0),	value=-1.6561000000000001
# State=(('ready', 'executing', 'configured', 'broken'), 0),	value=-9.347259808001487
# State=(('ready', 'repairing', 'broken', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'broken', 'broken'), 4),	value=0.0
# State=(('ready', 'ready', 'executing', 'broken'), 3),	value=-10.339176691360066
# State=(('ready', 'configured', 'broken', 'repairing'), 0),	value=-2.484185158113484
# State=(('ready', 'ready', 'ready', 'broken'), 2),	value=-6.896888104407958
# State=(('ready', 'broken', 'configured', 'repairing'), 2),	value=-5.069094620126094
# State=(('ready', 'broken', 'executing', 'repairing'), 0),	value=-5.80525902222406
# State=(('ready', 'broken', 'executing', 'broken'), 2),	value=-14.30525902222406
# State=(('ready', 'repairing', 'configured', 'executing'), 2),	value=-0.7971346202472097
# State=(('ready', 'ready', 'configured', 'broken'), 3),	value=-10.339176691360066
# State=(('ready', 'executing', 'repairing', 'repairing'), 0),	value=-1.87863382720134
# State=(('ready', 'broken', 'broken', 'executing'), 3),	value=0.0
# State=(('ready', 'broken', 'repairing', 'executing'), 3),	value=0.0
# State=(('ready', 'executing', 'ready', 'ready'), 2),	value=-1.1152590222240604
# State=(('ready', 'repairing', 'broken', 'broken'), 0),	value=-7.980253643016295
# State=(('ready', 'repairing', 'repairing', 'broken'), 0),	value=-6.027831428113403
# State=(('ready', 'repairing', 'ready', 'configured'), 3),	value=-0.465262951111203
# State=(('ready', 'ready', 'ready', 'configured'), 2),	value=-1.0716235270344434
# State=(('ready', 'broken', 'executing', 'configured'), 2),	value=-5.418736656000084
# State=(('ready', 'broken', 'configured', 'ready'), 2),	value=-5.10240929367094
# State=(('ready', 'broken', 'executing', 'ready'), 0),	value=-5.839176691360066
# State=(('ready', 'broken', 'repairing', 'broken'), 0),	value=-10.473433643016296
# State=(('ready', 'repairing', 'configured', 'ready'), 2),	value=-1.04417463635572
# State=(('ready', 'configured', 'ready', 'executing'), 3),	value=0.0
# State=(('ready', 'executing', 'broken', 'ready'), 0),	value=-2.239176691360067
# State=(('ready', 'executing', 'broken', 'executing'), 3),	value=0.0
# State=(('ready', 'configured', 'configured', 'broken'), 0),	value=-8.663209004897732
# State=(('ready', 'executing', 'repairing', 'ready'), 0),	value=-1.9033598080014889
# State=(('ready', 'broken', 'broken', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'repairing', 'broken', 'executing'), 2),	value=-1.0929026721602157
# State=(('ready', 'broken', 'repairing', 'ready'), 3),	value=-0.41873665600008275
# State=(('ready', 'ready', 'broken', 'broken'), 3),	value=-10.339176691360066
# State=(('ready', 'broken', 'configured', 'configured'), 0),	value=-5.62548303784869
# State=(('ready', 'repairing', 'executing', 'broken'), 2),	value=-7.658333827201338
# State=(('ready', 'broken', 'executing', 'executing'), 3),	value=0.0
# State=(('ready', 'ready', 'repairing', 'broken'), 4),	value=0.0
# State=(('ready', 'repairing', 'broken', 'ready'), 3),	value=-0.41873665600008275
# State=-1,	value=0.0

# %%
print_q_value_function(q_value_function)
# Out:
# Q-value function:
# State=(('ready', 'ready', 'ready', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.9397571727201481
#
# State=(('ready', 'executing', 'repairing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.9033598080014889
#
# State=(('ready', 'configured', 'configured', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.1601940403952447
#
# State=(('ready', 'broken', 'broken', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-11.103828737577501
#
# State=(('ready', 'configured', 'executing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.972
#
# State=(('ready', 'executing', 'ready', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.0342590222240604
#
# State=(('ready', 'configured', 'repairing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7174211582224888
#
# State=(('ready', 'configured', 'broken', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.5141683643038446
#
# State=(('ready', 'repairing', 'ready', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.8457814554481333
#
# State=(('ready', 'ready', 'broken', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.335766642302136
#
# State=(('ready', 'repairing', 'executing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.0345798080014887
#
# State=(('ready', 'executing', 'ready', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.729
#
# State=(('ready', 'broken', 'configured', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-5.2923363024002406
#
# State=(('ready', 'executing', 'executing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.9
#
# State=(('ready', 'broken', 'repairing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-4.719656375086114
#
# State=(('ready', 'executing', 'configured', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.1152590222240604
#
# State=(('ready', 'broken', 'ready', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-5.162934734063821
#
# State=(('ready', 'ready', 'repairing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.825771214143344
#
# State=(('ready', 'configured', 'executing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.2772590222240607
#
# State=(('ready', 'broken', 'ready', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-4.863102672160216
#
# State=(('ready', 'repairing', 'broken', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.253461260657439
#
# State=(('ready', 'configured', 'repairing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.9397571727201481
#
# State=(('ready', 'broken', 'executing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-5.5
#
# State=(('ready', 'configured', 'ready', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7971346202472098
#
# State=(('ready', 'repairing', 'broken', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.980253643016294
#
# State=(('ready', 'ready', 'configured', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.019470634744869
#
# State=(('ready', 'repairing', 'broken', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.2021899780719223
#
# State=(('ready', 'executing', 'ready', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.0037331200016544
#
# State=(('ready', 'broken', 'configured', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-5.592168364303846
#
# State=(('ready', 'ready', 'broken', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.392734734063821
#
# State=(('ready', 'executing', 'executing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.239176691360067
#
# State=(('ready', 'ready', 'broken', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-8.755837381129217
#
# State=(('ready', 'repairing', 'repairing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.7812135512081095
#
# State=(('ready', 'ready', 'broken', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-2.092902672160216
#
# State=(('ready', 'configured', 'broken', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.484185158113484
#
# State=(('ready', 'repairing', 'repairing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-6.0278314281134024
#
# State=(('ready', 'repairing', 'repairing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7431940927290097
#
# State=(('ready', 'repairing', 'executing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.00985382720134
#
# State=(('ready', 'broken', 'ready', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-5.132951527873461
#
# State=(('ready', 'ready', 'repairing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.868015056897899
#
# State=(('ready', 'broken', 'executing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-5.839176691360067
#
# State=(('ready', 'configured', 'ready', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.04417463635572
#
# State=(('ready', 'ready', 'repairing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-6.586479364570447
#
# State=(('ready', 'ready', 'executing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-8.65833382720134
#
# State=(('ready', 'ready', 'ready', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.9175235712703822
#
# State=(('ready', 'ready', 'repairing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.6456790424002399
#
# State=(('ready', 'repairing', 'configured', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.207199293967164
#
# State=(('ready', 'executing', 'broken', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-10.274733120001653
#
# State=(('ready', 'ready', 'executing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.122059808001489
#
# State=(('ready', 'executing', 'configured', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.0847331200016543
#
# State=(('ready', 'repairing', 'configured', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.9175235712703822
#
# State=(('ready', 'executing', 'broken', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.2052590222240607
#
# State=(('ready', 'ready', 'configured', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.0716235270344434
#
# State=(('ready', 'configured', 'executing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.2467331200016547
#
# State=(('ready', 'ready', 'configured', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.896888104407959
#
# State=(('ready', 'repairing', 'broken', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.983612404944194
#
# State=(('ready', 'executing', 'repairing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.761280444481205
#
# State=(('ready', 'configured', 'broken', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.54748303784869
#
# State=(('ready', 'configured', 'configured', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-8.663209004897734
#
# State=(('ready', 'broken', 'broken', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-16.282228278714662
#
# State=(('ready', 'broken', 'configured', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-5.562185158113485
#
# State=(('ready', 'executing', 'repairing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.87863382720134
#
# State=(('ready', 'repairing', 'ready', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.868015056897899
#
# State=(('ready', 'configured', 'broken', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-9.617597090143574
#
# State=(('ready', 'configured', 'configured', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.1327451497165213
#
# State=(('ready', 'broken', 'broken', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-11.08197098026473
#
# State=(('ready', 'repairing', 'executing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.0620531200016545
#
# State=(('ready', 'repairing', 'ready', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-6.5864793645704465
#
# State=(('ready', 'repairing', 'executing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.892500444481205
#
# State=(('ready', 'repairing', 'ready', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.825771214143344
#
# State=(('ready', 'repairing', 'repairing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.5811111381602159
#
# State=(('ready', 'ready', 'ready', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.964461174330999
#
# State=(('ready', 'executing', 'configured', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.1491766913600667
#
# State=(('ready', 'ready', 'executing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.18005902222406
#
# State=(('ready', 'broken', 'repairing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-10.473433643016296
#
# State=(('ready', 'ready', 'ready', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.207199293967163
#
# State=(('ready', 'repairing', 'configured', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.964461174330999
#
# State=(('ready', 'executing', 'broken', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.2768629904000743
#
# State=(('ready', 'executing', 'configured', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-9.347259808001485
#
# State=(('ready', 'broken', 'repairing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-4.695369978071922
#
# State=(('ready', 'ready', 'ready', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7174211582224888
#
# State=(('ready', 'configured', 'ready', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.019470634744869
#
# State=(('ready', 'repairing', 'broken', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.226476375086114
#
# State=(('ready', 'ready', 'executing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.8748
#
# State=(('ready', 'configured', 'executing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.311176691360067
#
# State=(('ready', 'repairing', 'configured', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7174211582224888
#
# State=(('ready', 'executing', 'broken', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.9
#
# State=(('ready', 'configured', 'executing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-9.509259808001488
#
# State=(('ready', 'configured', 'repairing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.207199293967164
#
# State=(('ready', 'ready', 'broken', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.36275152787346
#
# State=(('ready', 'broken', 'configured', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-5.6254830378486895
#
# State=(('ready', 'configured', 'repairing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.9175235712703822
#
# State=(('ready', 'executing', 'repairing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.9308331200016544
#
# State=(('ready', 'ready', 'configured', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.7971346202472098
#
# State=(('ready', 'executing', 'executing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.2768629904000743
#
# State=(('ready', 'configured', 'configured', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.190692807816048
#
# State=(('ready', 'broken', 'broken', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-11.128115134591694
#
# State=(('ready', 'executing', 'ready', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-8.512533827201338
#
# State=(('ready', 'broken', 'configured', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-12.695597090143574
#
# State=(('ready', 'repairing', 'repairing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.76120330990332
#
# State=(('ready', 'executing', 'executing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-10.274733120001653
#
# State=(('ready', 'executing', 'ready', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-1.976259808001489
#
# State=(('ready', 'executing', 'repairing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.6561
#
# State=(('ready', 'executing', 'executing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-2.2052590222240607
#
# State=(('ready', 'configured', 'configured', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.8857051336080108
#
# State=(('ready', 'broken', 'broken', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-10.885251164449775
#
# State=(('ready', 'configured', 'broken', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-2.21433630240024
#
# State=(('ready', 'ready', 'repairing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.8457814554481333
#
# State=(('ready', 'ready', 'executing', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.1495331200016543
#
# State=(('ready', 'repairing', 'ready', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.6456790424002399
#
# State=(('ready', 'repairing', 'configured', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-1.9397571727201481
#
# State=(('ready', 'broken', 'repairing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-4.746641260657439
#
# State=(('ready', 'repairing', 'executing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.78732
#
# State=(('ready', 'executing', 'broken', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.239176691360067
#
# State=(('ready', 'broken', 'executing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-5.876862990400076
#
# State=(('ready', 'configured', 'ready', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-2.0716235270344434
#
# State=(('ready', 'broken', 'ready', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-11.526037381129218
#
# State=(('ready', 'broken', 'executing', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-13.874733120001654
#
# State=(('ready', 'configured', 'ready', 'broken'), 0):
# 	Action=('cleaning', 0),	Value=-7.896888104407959
#
# State=(('ready', 'broken', 'ready', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-5.105966642302136
#
# State=(('ready', 'broken', 'repairing', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-4.476792404944193
#
# State=(('ready', 'broken', 'executing', 'repairing'), 0):
# 	Action=('cleaning', 0),	Value=-5.805259022224059
#
# State=(('ready', 'ready', 'configured', 'ready'), 0):
# 	Action=('cleaning', 0),	Value=-2.04417463635572
#
# State=(('ready', 'executing', 'configured', 'executing'), 0):
# 	Action=('cleaning', 0),	Value=-1.81
#
# State=(('ready', 'configured', 'repairing', 'configured'), 0):
# 	Action=('cleaning', 0),	Value=-1.964461174330999
#
# State=(('ready', 'ready', 'ready', 'ready'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.0441746363557203
# 	Action=('config_film_deposition', 2),	Value=-1.04417463635572
#
# State=(('ready', 'executing', 'repairing', 'ready'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3768629904000744
# 	Action=('repaired_film_deposition', 2),	Value=-1.0037331200016544
#
# State=(('ready', 'configured', 'configured', 'ready'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.2891044893280497
# 	Action=('checked_film_deposition', 2),	Value=-1.2891044893280497
#
# State=(('ready', 'broken', 'broken', 'ready'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.226476375086115
# 	Action=('restore_film_deposition', 2),	Value=-13.719656375086114
#
# State=(('ready', 'configured', 'executing', 'executing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.08
# 	Action=('film_deposition', 2),	Value=-5.0
#
# State=(('ready', 'executing', 'ready', 'configured'), 2):
# 	Action=('film_deposition', 1),	Value=-1.4187366560000827
# 	Action=('config_film_deposition', 2),	Value=-1.149176691360067
#
# State=(('ready', 'configured', 'repairing', 'executing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-0.7971346202472098
# 	Action=('repaired_film_deposition', 2),	Value=-0.7971346202472098
#
# State=(('ready', 'configured', 'broken', 'ready'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.6824092936709387
# 	Action=('restore_film_deposition', 2),	Value=-10.939757172720148
#
# State=(('ready', 'repairing', 'ready', 'ready'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.939757172720148
# 	Action=('config_film_deposition', 2),	Value=-0.939757172720148
#
# State=(('ready', 'ready', 'broken', 'repairing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.4841851581134844
# 	Action=('restore_film_deposition', 2),	Value=-10.825771214143344
#
# State=(('ready', 'repairing', 'executing', 'ready'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.1495331200016543
# 	Action=('film_deposition', 2),	Value=-5.376862990400075
#
# State=(('ready', 'executing', 'ready', 'executing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.0
# 	Action=('config_film_deposition', 2),	Value=-0.81
#
# State=(('ready', 'broken', 'configured', 'executing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.71742115822249
# 	Action=('checked_film_deposition', 2),	Value=-4.769262558222489
#
# State=(('ready', 'executing', 'executing', 'executing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.0
# 	Action=('film_deposition', 2),	Value=-5.0
#
# State=(('ready', 'broken', 'repairing', 'ready'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.761203309903319
# 	Action=('repaired_film_deposition', 2),	Value=-4.132951527873461
#
# State=(('ready', 'executing', 'configured', 'ready'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3768629904000744
# 	Action=('checked_film_deposition', 2),	Value=-1.239176691360067
#
# State=(('ready', 'broken', 'ready', 'configured'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.8680150568979
# 	Action=('config_film_deposition', 2),	Value=-4.6254830378486895
#
# State=(('ready', 'ready', 'repairing', 'repairing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.9175235712703823
# 	Action=('repaired_film_deposition', 2),	Value=-0.9175235712703821
#
# State=(('ready', 'configured', 'executing', 'ready'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.419176691360067
# 	Action=('film_deposition', 2),	Value=-5.376862990400075
#
# State=(('ready', 'broken', 'ready', 'executing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.64567904240024
# 	Action=('config_film_deposition', 2),	Value=-4.2923363024002406
#
# State=(('ready', 'repairing', 'broken', 'configured'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.392734734063821
# 	Action=('restore_film_deposition', 2),	Value=-10.78121355120811
#
# State=(('ready', 'configured', 'repairing', 'ready'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.0441746363557203
# 	Action=('repaired_film_deposition', 2),	Value=-1.0441746363557203
#
# State=(('ready', 'broken', 'executing', 'executing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.78732
# 	Action=('film_deposition', 2),	Value=-5.0
#
# State=(('ready', 'configured', 'ready', 'executing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-0.8857051336080107
# 	Action=('config_film_deposition', 2),	Value=-0.8857051336080108
#
# State=(('ready', 'repairing', 'broken', 'broken'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-7.755837381129217
# 	Action=('restore_film_deposition', 2),	Value=-15.027831428113402
#
# State=(('ready', 'ready', 'configured', 'repairing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.1327451497165213
# 	Action=('checked_film_deposition', 2),	Value=-1.132745149716521
#
# State=(('ready', 'repairing', 'broken', 'repairing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.335766642302136
# 	Action=('restore_film_deposition', 2),	Value=-10.74319409272901
#
# State=(('ready', 'executing', 'ready', 'ready'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3768629904000744
# 	Action=('config_film_deposition', 2),	Value=-1.1152590222240604
#
# State=(('ready', 'broken', 'configured', 'ready'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.939757172720148
# 	Action=('checked_film_deposition', 2),	Value=-5.102409293670939
#
# State=(('ready', 'ready', 'broken', 'configured'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.54748303784869
# 	Action=('restore_film_deposition', 2),	Value=-10.8680150568979
#
# State=(('ready', 'executing', 'executing', 'ready'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3768629904000744
# 	Action=('film_deposition', 2),	Value=-5.376862990400075
#
# State=(('ready', 'ready', 'broken', 'broken'), 2):
# 	Action=('config_film_deposition', 1),	Value=-8.617597090143574
# 	Action=('restore_film_deposition', 2),	Value=-15.586479364570447
#
# State=(('ready', 'repairing', 'repairing', 'configured'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.8680150568978992
# 	Action=('repaired_film_deposition', 2),	Value=-0.8680150568978992
#
# State=(('ready', 'ready', 'broken', 'executing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.2143363024002398
# 	Action=('restore_film_deposition', 2),	Value=-10.64567904240024
#
# State=(('ready', 'configured', 'broken', 'repairing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.6490946201260939
# 	Action=('restore_film_deposition', 2),	Value=-10.917523571270383
#
# State=(('ready', 'repairing', 'repairing', 'broken'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-5.586479364570447
# 	Action=('repaired_film_deposition', 2),	Value=-5.5864793645704465
#
# State=(('ready', 'repairing', 'repairing', 'repairing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.825771214143344
# 	Action=('repaired_film_deposition', 2),	Value=-0.825771214143344
#
# State=(('ready', 'repairing', 'executing', 'repairing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.122059808001489
# 	Action=('film_deposition', 2),	Value=-5.339176691360067
#
# State=(('ready', 'broken', 'ready', 'ready'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.845781455448133
# 	Action=('config_film_deposition', 2),	Value=-4.592168364303846
#
# State=(('ready', 'ready', 'repairing', 'configured'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.9644611743309991
# 	Action=('repaired_film_deposition', 2),	Value=-0.9644611743309991
#
# State=(('ready', 'broken', 'executing', 'ready'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.034579808001489
# 	Action=('film_deposition', 2),	Value=-5.376862990400075
#
# State=(('ready', 'configured', 'ready', 'ready'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.1601940403952447
# 	Action=('config_film_deposition', 2),	Value=-1.1601940403952447
#
# State=(('ready', 'ready', 'repairing', 'broken'), 2):
# 	Action=('config_film_deposition', 1),	Value=-6.207199293967164
# 	Action=('repaired_film_deposition', 2),	Value=-6.207199293967163
#
# State=(('ready', 'ready', 'executing', 'broken'), 2):
# 	Action=('config_film_deposition', 1),	Value=-8.509259808001488
# 	Action=('film_deposition', 2),	Value=-14.30525902222406
#
# State=(('ready', 'ready', 'ready', 'repairing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.0194706347448692
# 	Action=('config_film_deposition', 2),	Value=-1.0194706347448692
#
# State=(('ready', 'ready', 'repairing', 'executing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.7174211582224888
# 	Action=('repaired_film_deposition', 2),	Value=-0.7174211582224888
#
# State=(('ready', 'repairing', 'configured', 'broken'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-6.896888104407959
# 	Action=('checked_film_deposition', 2),	Value=-6.896888104407958
#
# State=(('ready', 'executing', 'broken', 'broken'), 2):
# 	Action=('film_deposition', 1),	Value=-10.30525902222406
# 	Action=('restore_film_deposition', 2),	Value=-16.761280444481205
#
# State=(('ready', 'ready', 'executing', 'repairing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.2467331200016545
# 	Action=('film_deposition', 2),	Value=-5.339176691360067
#
# State=(('ready', 'executing', 'configured', 'repairing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3391766913600671
# 	Action=('checked_film_deposition', 2),	Value=-1.2052590222240605
#
# State=(('ready', 'repairing', 'configured', 'repairing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.0194706347448692
# 	Action=('checked_film_deposition', 2),	Value=-1.0194706347448692
#
# State=(('ready', 'executing', 'broken', 'repairing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3391766913600671
# 	Action=('restore_film_deposition', 2),	Value=-10.878633827201341
#
# State=(('ready', 'ready', 'configured', 'configured'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.1906928078160484
# 	Action=('checked_film_deposition', 2),	Value=-1.1906928078160481
#
# State=(('ready', 'configured', 'executing', 'repairing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.3852590222240604
# 	Action=('film_deposition', 2),	Value=-5.339176691360067
#
# State=(('ready', 'ready', 'configured', 'broken'), 2):
# 	Action=('config_film_deposition', 1),	Value=-7.663209004897733
# 	Action=('checked_film_deposition', 2),	Value=-7.663209004897733
#
# State=(('ready', 'repairing', 'broken', 'executing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.092902672160216
# 	Action=('restore_film_deposition', 2),	Value=-10.581111138160216
#
# State=(('ready', 'executing', 'repairing', 'broken'), 2):
# 	Action=('film_deposition', 1),	Value=-10.30525902222406
# 	Action=('repaired_film_deposition', 2),	Value=-7.512533827201339
#
# State=(('ready', 'configured', 'broken', 'configured'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.7194255976096555
# 	Action=('restore_film_deposition', 2),	Value=-10.964461174331
#
# State=(('ready', 'configured', 'configured', 'broken'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-8.51467667210859
# 	Action=('checked_film_deposition', 2),	Value=-8.51467667210859
#
# State=(('ready', 'broken', 'broken', 'broken'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-16.980253643016294
# 	Action=('restore_film_deposition', 2),	Value=-19.473433643016296
#
# State=(('ready', 'broken', 'configured', 'repairing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.917523571270381
# 	Action=('checked_film_deposition', 2),	Value=-5.069094620126093
#
# State=(('ready', 'executing', 'repairing', 'repairing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3391766913600671
# 	Action=('repaired_film_deposition', 2),	Value=-0.9762598080014889
#
# State=(('ready', 'repairing', 'ready', 'configured'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.9644611743309991
# 	Action=('config_film_deposition', 2),	Value=-0.9644611743309991
#
# State=(('ready', 'configured', 'broken', 'broken'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-9.575107877937302
# 	Action=('restore_film_deposition', 2),	Value=-16.207199293967165
#
# State=(('ready', 'configured', 'configured', 'repairing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.2586057219072455
# 	Action=('checked_film_deposition', 2),	Value=-1.2586057219072457
#
# State=(('ready', 'broken', 'broken', 'repairing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.202189978071923
# 	Action=('restore_film_deposition', 2),	Value=-13.695369978071922
#
# State=(('ready', 'repairing', 'executing', 'configured'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.1800590222240601
# 	Action=('film_deposition', 2),	Value=-5.418736656000083
#
# State=(('ready', 'repairing', 'ready', 'broken'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-6.207199293967163
# 	Action=('config_film_deposition', 2),	Value=-6.207199293967164
#
# State=(('ready', 'repairing', 'executing', 'broken'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-7.658333827201339
# 	Action=('film_deposition', 2),	Value=-14.305259022224062
#
# State=(('ready', 'repairing', 'ready', 'repairing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.9175235712703821
# 	Action=('config_film_deposition', 2),	Value=-0.9175235712703821
#
# State=(('ready', 'repairing', 'repairing', 'executing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.6456790424002399
# 	Action=('repaired_film_deposition', 2),	Value=-0.6456790424002399
#
# State=(('ready', 'ready', 'ready', 'configured'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.0716235270344436
# 	Action=('config_film_deposition', 2),	Value=-1.0716235270344436
#
# State=(('ready', 'executing', 'configured', 'configured'), 2):
# 	Action=('film_deposition', 1),	Value=-1.4187366560000827
# 	Action=('checked_film_deposition', 2),	Value=-1.2768629904000746
#
# State=(('ready', 'ready', 'executing', 'configured'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.311176691360067
# 	Action=('film_deposition', 2),	Value=-5.418736656000083
#
# State=(('ready', 'broken', 'repairing', 'broken'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-15.027831428113402
# 	Action=('repaired_film_deposition', 2),	Value=-10.526037381129218
#
# State=(('ready', 'ready', 'ready', 'broken'), 2):
# 	Action=('config_film_deposition', 1),	Value=-6.896888104407959
# 	Action=('config_film_deposition', 2),	Value=-6.896888104407959
#
# State=(('ready', 'repairing', 'configured', 'configured'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.0716235270344436
# 	Action=('checked_film_deposition', 2),	Value=-1.0716235270344436
#
# State=(('ready', 'executing', 'broken', 'configured'), 2):
# 	Action=('film_deposition', 1),	Value=-1.4187366560000827
# 	Action=('restore_film_deposition', 2),	Value=-10.930833120001655
#
# State=(('ready', 'executing', 'configured', 'broken'), 2):
# 	Action=('film_deposition', 1),	Value=-10.30525902222406
# 	Action=('checked_film_deposition', 2),	Value=-9.27473312000165
#
# State=(('ready', 'broken', 'repairing', 'repairing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.74319409272901
# 	Action=('repaired_film_deposition', 2),	Value=-4.105966642302136
#
# State=(('ready', 'ready', 'ready', 'executing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.7971346202472098
# 	Action=('config_film_deposition', 2),	Value=-0.7971346202472098
#
# State=(('ready', 'configured', 'ready', 'repairing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.1327451497165213
# 	Action=('config_film_deposition', 2),	Value=-1.1327451497165213
#
# State=(('ready', 'repairing', 'broken', 'ready'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.36275152787346
# 	Action=('restore_film_deposition', 2),	Value=-10.761203309903319
#
# State=(('ready', 'ready', 'executing', 'executing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.9720000000000001
# 	Action=('film_deposition', 2),	Value=-5.0
#
# State=(('ready', 'configured', 'executing', 'configured'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.4568629904000745
# 	Action=('film_deposition', 2),	Value=-5.418736656000083
#
# State=(('ready', 'repairing', 'configured', 'executing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.7971346202472098
# 	Action=('checked_film_deposition', 2),	Value=-0.7971346202472098
#
# State=(('ready', 'executing', 'broken', 'executing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.0
# 	Action=('restore_film_deposition', 2),	Value=-10.6561
#
# State=(('ready', 'configured', 'executing', 'broken'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-9.454733120001652
# 	Action=('film_deposition', 2),	Value=-14.305259022224062
#
# State=(('ready', 'configured', 'repairing', 'broken'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-6.896888104407959
# 	Action=('repaired_film_deposition', 2),	Value=-6.896888104407959
#
# State=(('ready', 'ready', 'broken', 'ready'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.5141683643038446
# 	Action=('restore_film_deposition', 2),	Value=-10.845781455448133
#
# State=(('ready', 'broken', 'configured', 'configured'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.964461174331
# 	Action=('checked_film_deposition', 2),	Value=-5.139425597609655
#
# State=(('ready', 'configured', 'repairing', 'repairing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.0194706347448692
# 	Action=('repaired_film_deposition', 2),	Value=-1.0194706347448692
#
# State=(('ready', 'executing', 'repairing', 'configured'), 2):
# 	Action=('film_deposition', 1),	Value=-1.4187366560000827
# 	Action=('repaired_film_deposition', 2),	Value=-1.0342590222240602
#
# State=(('ready', 'ready', 'configured', 'executing'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.8857051336080108
# 	Action=('checked_film_deposition', 2),	Value=-0.8857051336080107
#
# State=(('ready', 'executing', 'executing', 'configured'), 2):
# 	Action=('film_deposition', 1),	Value=-1.4187366560000827
# 	Action=('film_deposition', 2),	Value=-5.418736656000083
#
# State=(('ready', 'configured', 'configured', 'configured'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.3229920086844982
# 	Action=('checked_film_deposition', 2),	Value=-1.3229920086844982
#
# State=(('ready', 'broken', 'broken', 'configured'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.253461260657438
# 	Action=('restore_film_deposition', 2),	Value=-13.746641260657439
#
# State=(('ready', 'executing', 'ready', 'broken'), 2):
# 	Action=('film_deposition', 1),	Value=-10.30525902222406
# 	Action=('config_film_deposition', 2),	Value=-8.347259808001485
#
# State=(('ready', 'broken', 'configured', 'broken'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-16.207199293967165
# 	Action=('checked_film_deposition', 2),	Value=-12.995107877937304
#
# State=(('ready', 'repairing', 'repairing', 'ready'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.8457814554481333
# 	Action=('repaired_film_deposition', 2),	Value=-0.8457814554481333
#
# State=(('ready', 'executing', 'executing', 'broken'), 2):
# 	Action=('film_deposition', 1),	Value=-10.30525902222406
# 	Action=('film_deposition', 2),	Value=-14.305259022224062
#
# State=(('ready', 'executing', 'ready', 'repairing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3391766913600671
# 	Action=('config_film_deposition', 2),	Value=-1.0847331200016543
#
# State=(('ready', 'executing', 'repairing', 'executing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.0
# 	Action=('repaired_film_deposition', 2),	Value=-0.729
#
# State=(('ready', 'executing', 'executing', 'repairing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3391766913600671
# 	Action=('film_deposition', 2),	Value=-5.339176691360067
#
# State=(('ready', 'configured', 'configured', 'executing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-0.984116815120012
# 	Action=('checked_film_deposition', 2),	Value=-0.984116815120012
#
# State=(('ready', 'broken', 'broken', 'executing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.983612404944195
# 	Action=('restore_film_deposition', 2),	Value=-13.476792404944193
#
# State=(('ready', 'configured', 'broken', 'executing'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.3492625582224886
# 	Action=('restore_film_deposition', 2),	Value=-10.71742115822249
#
# State=(('ready', 'ready', 'repairing', 'ready'), 2):
# 	Action=('config_film_deposition', 1),	Value=-0.939757172720148
# 	Action=('repaired_film_deposition', 2),	Value=-0.939757172720148
#
# State=(('ready', 'ready', 'executing', 'ready'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.2772590222240605
# 	Action=('film_deposition', 2),	Value=-5.376862990400075
#
# State=(('ready', 'repairing', 'ready', 'executing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.7174211582224888
# 	Action=('config_film_deposition', 2),	Value=-0.7174211582224888
#
# State=(('ready', 'repairing', 'configured', 'ready'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-1.04417463635572
# 	Action=('checked_film_deposition', 2),	Value=-1.0441746363557203
#
# State=(('ready', 'broken', 'repairing', 'configured'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.78121355120811
# 	Action=('repaired_film_deposition', 2),	Value=-4.162934734063821
#
# State=(('ready', 'repairing', 'executing', 'executing'), 2):
# 	Action=('repaired_film_deposition', 1),	Value=-0.8748
# 	Action=('film_deposition', 2),	Value=-5.0
#
# State=(('ready', 'executing', 'broken', 'ready'), 2):
# 	Action=('film_deposition', 1),	Value=-1.3768629904000744
# 	Action=('restore_film_deposition', 2),	Value=-10.90335980800149
#
# State=(('ready', 'broken', 'executing', 'configured'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.062053120001654
# 	Action=('film_deposition', 2),	Value=-5.418736656000083
#
# State=(('ready', 'configured', 'ready', 'configured'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.1906928078160484
# 	Action=('config_film_deposition', 2),	Value=-1.1906928078160484
#
# State=(('ready', 'broken', 'ready', 'broken'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-15.586479364570447
# 	Action=('config_film_deposition', 2),	Value=-11.695597090143574
#
# State=(('ready', 'broken', 'executing', 'broken'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-16.892500444481204
# 	Action=('film_deposition', 2),	Value=-14.305259022224062
#
# State=(('ready', 'configured', 'ready', 'broken'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-7.663209004897732
# 	Action=('config_film_deposition', 2),	Value=-7.663209004897733
#
# State=(('ready', 'broken', 'ready', 'repairing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.825771214143344
# 	Action=('config_film_deposition', 2),	Value=-4.562185158113485
#
# State=(('ready', 'broken', 'repairing', 'executing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-10.581111138160216
# 	Action=('repaired_film_deposition', 2),	Value=-3.863102672160216
#
# State=(('ready', 'broken', 'executing', 'repairing'), 2):
# 	Action=('restore_film_deposition', 1),	Value=-11.00985382720134
# 	Action=('film_deposition', 2),	Value=-5.339176691360067
#
# State=(('ready', 'ready', 'configured', 'ready'), 2):
# 	Action=('config_film_deposition', 1),	Value=-1.1601940403952447
# 	Action=('checked_film_deposition', 2),	Value=-1.1601940403952444
#
# State=(('ready', 'executing', 'configured', 'executing'), 2):
# 	Action=('film_deposition', 1),	Value=-1.0
# 	Action=('checked_film_deposition', 2),	Value=-0.9
#
# State=(('ready', 'configured', 'repairing', 'configured'), 2):
# 	Action=('checked_film_deposition', 1),	Value=-1.0716235270344436
# 	Action=('repaired_film_deposition', 2),	Value=-1.0716235270344436
#
# State=(('ready', 'ready', 'repairing', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'broken', 'repairing', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'configured', 'ready', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'configured', 'broken', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'ready', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'broken', 'ready', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'repairing', 'ready', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'repairing', 'broken', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'ready', 'ready', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'broken', 'ready', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'executing', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'broken', 'executing', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'executing', 'ready', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'executing', 'broken', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'configured', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'broken', 'configured', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'configured', 'ready', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'configured', 'broken', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'broken', 'broken', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'ready', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'broken', 'ready', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'ready', 'executing', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'broken', 'executing', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'executing', 'ready', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'executing', 'broken', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'repairing', 'ready', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'repairing', 'broken', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'broken', 'broken', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.4187366560000828
#
# State=(('ready', 'ready', 'ready', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'broken', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'broken', 'broken', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'ready', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'ready', 'broken', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'ready', 'configured', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'broken', 'configured', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'broken', 'broken', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'configured', 'ready', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'configured', 'broken', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'ready', 'repairing', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'broken', 'repairing', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'repairing', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'broken', 'repairing', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'repairing', 'ready', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'repairing', 'broken', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'repairing', 'ready', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'repairing', 'broken', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'configured', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.46526295111120297
#
# State=(('ready', 'broken', 'configured', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'ready', 'broken', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.46526295111120297
#
# State=(('ready', 'broken', 'broken', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'ready', 'configured', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'broken', 'configured', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'broken', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'configured', 'ready', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'configured', 'broken', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'configured', 'ready', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'configured', 'broken', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'repairing', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'broken', 'repairing', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'ready', 'executing', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.46526295111120297
#
# State=(('ready', 'broken', 'executing', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'executing', 'ready', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'executing', 'broken', 'configured'), 3):
# 	Action=('checked_resist_coating', 3),	Value=-0.4652629511112031
#
# State=(('ready', 'broken', 'ready', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'ready', 'executing', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'broken', 'executing', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'executing', 'ready', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'executing', 'broken', 'broken'), 3):
# 	Action=('restore_resist_coating', 3),	Value=-10.339176691360066
#
# State=(('ready', 'broken', 'ready', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.37686299040007454
#
# State=(('ready', 'ready', 'repairing', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'broken', 'repairing', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'executing', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'broken', 'executing', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'executing', 'ready', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'executing', 'broken', 'repairing'), 3):
# 	Action=('repaired_resist_coating', 3),	Value=-0.3768629904000745
#
# State=(('ready', 'ready', 'broken', 'ready'), 3):
# 	Action=('config_resist_coating', 3),	Value=-0.41873665600008275
#
# State=(('ready', 'repairing', 'ready', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'repairing', 'broken', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'ready', 'configured', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'broken', 'configured', 'executing'), 3):
# 	Action=('resist_coating', 3),	Value=0.0
#
# State=(('ready', 'configured', 'ready', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'configured', 'ready', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'configured', 'broken', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'configured', 'broken', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'ready', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'ready', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'ready', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'ready', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'executing', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'executing', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'executing', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'executing', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'executing', 'ready', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'executing', 'ready', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'executing', 'broken', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'executing', 'broken', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'broken', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'broken', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'broken', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'broken', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'repairing', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'repairing', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'repairing', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'repairing', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'repairing', 'ready', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'repairing', 'ready', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'repairing', 'broken', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'repairing', 'broken', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'configured', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'ready', 'configured', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'configured', 'ready'), 4):
# 	Action=undefined,	Value=0.0
#
# State=(('ready', 'broken', 'configured', 'broken'), 4):
# 	Action=undefined,	Value=0.0
#
# State=-1:
# 	Action=undefined,	Value=0.0

# %% [markdown]
# In the manufacturing processes only some machines have double copies. Basically, one machine is more costly and wear out respect to the other. The optimal policy will prefer always the choice of the best service. In fact, from the calculation of the optimal policy of the manufacturing process phase we observe that:
# - the planner when performs the action `film_deposition` preferred using service `service_film_deposition1` (service `1`) because this service had a more convenient cost respect to `service_film_deposition2`;
# - the planner when performs the action `resist_coating` preferred using service `service_resist_coating1` (service `3`) because this service had a more convenient cost respect to `service_resist_coating2`;
# - the planner when performs the action `development` preferred using service `service_development1` (service `6`) because this service had a more convenient cost respect to `service_development2`;
# - the planner when performs the action `etching` preferred using service `service_etching1` (service `8`) because this service had a more convenient cost and less probability to break respect to `service_etching2`.
