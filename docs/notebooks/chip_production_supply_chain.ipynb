# %%
from mdp_dp_rl.algorithms.dp.dp_analytic import DPAnalytic
from stochastic_service_composition.declare_utils import *
from docs.notebooks.utils import render_service, render_target, render_composition_mdp,  \
    print_policy_data, print_value_function, print_q_value_function
from stochastic_service_composition.composition_mdp import composition_mdp
from stochastic_service_composition.services import build_service_from_transitions, Service
from stochastic_service_composition.target import build_target_from_transitions

# %% [markdown]
# ## Use case for "Stochastic Service Composition with Industrial APIs" - Chip Production.
#
# In this notebook, we present the implementation of the use case for "Stochastic Service Composition with Industrial APIs" about chip production.

# %% [markdown]
# # Available Services
#
# In the following we provide definitions about available services:

# %%
LOW_PROB = 0.05

# probabilities of being broken after an action
DEFAULT_BROKEN_PROB = LOW_PROB
BROKEN_PROB = 0.5
HIGH_BROKEN_PROB = 0.7

# default probability of being unemployable after the configuration
DEFAULT_UNEMPLOYABLE_PROB = LOW_PROB
HIGH_UNEMPLOYABLE_PROB = 0.5

# costs of the machines that perform their job in different countries
DEFAULT_USA_REWARD = -1.0
WAR_REWARD = -3.0
USA_REWARD = -2.0
HIGH_USA_REWARD = -5.0
UK_REWARD = -6.8
CHINA_REWARD = -11.7
TAIWAN_REWARD = -12.2
RUSSIA_REWARD = -9.12 # we have to take into the account political problems
NORWAY_REWARD = -7.16
BRAZIL_REWARD = -6.7
FRANCE_REWARD = -7.6
AUSTRALIA_REWARD = -14.0
INDIA_REWARD = -13.1
BELGIUM_REWARD = -7.6
SWITZERLAND_REWARD = -8.0
CANADA_REWARD = -1.8
PERU_REWARD = -6.0
AUSTRIA_REWARD = -8.38
MALAYSIA_REWARD = -14.73
TURKEY_REWARD = -10.16
KAZAKHSTAN_REWARD = -10.4
CHILE_REWARD = -7.8
BOLIVIA_REWARD = -6.8
ARGENTINA_REWARD = -8.55
MOROCCO_REWARD = -7.9
JAPAN_REWARD = -10.1
SOUTH_KOREA = -10.7
NETHERLANDS_REWARD = -7.5

# default reward when the service becomes broken
DEFAULT_BROKEN_REWARD = -10.0

# %%
# all the atomic actions for the task
PICK_BUY_DESIGN = "pick_buy_design"
PICK_SILICON = "pick_silicon"
PICK_WAFER = "pick_wafer"
PICK_BORON = "pick_boron"
PICK_PHOSPHOR = "pick_phosphor"
PICK_ALUMINUM = "pick_aluminum"
PICK_RESIST = "pick_resist"
PICK_PLASTIC = "pick_plastic"
PICK_CHEMICALS = "pick_chemicals"
PICK_COPPER_FRAME = "pick_copper_frame"
CLEANING = "cleaning"
CONFIG_FILM_DEPOSITION = "config_film_deposition"
CHECKED_FILM_DEPOSITION = "checked_film_deposition"
FILM_DEPOSITION = "film_deposition"
CONFIG_RESIST_COATING = "config_resist_coating"
CHECKED_RESIST_COATING = "checked_resist_coating"
RESIST_COATING = "resist_coating"
EXPOSURE = "exposure"
CHECK_EXPOSURE = "check_exposure"
CONFIG_DEVELOPMENT = "config_development"
CHECKED_DEVELOPMENT = "checked_development"
DEVELOPMENT = "development"
ETCHING = "etching"
CHECK_ETCHING = "check_etching"
CONFIG_IMPURITIES_IMPLANTATION = "config_impurities_implantation"
CHECKED_IMPURITIES_IMPLANTATION = "checked_impurities_implantation"
IMPURITIES_IMPLANTATION = "impurities_implantation"
ACTIVATION = "activation"
RESIST_STRIPPING = "resist_stripping"
CHECK_RESIST_STRIPPING = "check_resist_stripping"
ASSEMBLY = "assembly"
TESTING ="testing"
PACKAGING = "packaging"

SYMBOLS_PHASE_1 = [
    PICK_BUY_DESIGN,
    PICK_SILICON,
    PICK_WAFER,
    PICK_BORON,
    PICK_PHOSPHOR,
    PICK_ALUMINUM,
    PICK_RESIST,
    PICK_PLASTIC,
    PICK_CHEMICALS,
    PICK_COPPER_FRAME
]

SYMBOLS_PHASE_2 = [
    CLEANING,
    CONFIG_FILM_DEPOSITION,
    CHECKED_FILM_DEPOSITION,
    FILM_DEPOSITION,
    CONFIG_RESIST_COATING,
    CHECKED_RESIST_COATING,
    RESIST_COATING,
    EXPOSURE,
    CHECK_EXPOSURE,
    CONFIG_DEVELOPMENT,
    CHECKED_DEVELOPMENT,
    DEVELOPMENT,
    ETCHING,
    CHECK_ETCHING,
    CONFIG_IMPURITIES_IMPLANTATION,
    CHECKED_IMPURITIES_IMPLANTATION,
    IMPURITIES_IMPLANTATION,
    ACTIVATION,
    RESIST_STRIPPING,
    CHECK_RESIST_STRIPPING,
    ASSEMBLY,
    TESTING,
    PACKAGING
]

# %%
# service names
DESIGN_SERVICE_NAME_USA = "design_usa"                                      # human
DESIGN_SERVICE_NAME_UK = "design_uk"                                        # human
DESIGN_SERVICE_NAME_CHINA = "design_china"                                  # human
DESIGN_SERVICE_NAME_TAIWAN = "design_taiwan"                                # human
SILICON_SERVICE_NAME_CHINA = "silicon_china"                                # warehouse
SILICON_SERVICE_NAME_RUSSIA = "silicon_russia"                              # warehouse
SILICON_SERVICE_NAME_NORWAY = "silicon_norway"                              # warehouse
SILICON_SERVICE_NAME_USA = "silicon_usa"                                    # warehouse
SILICON_SERVICE_NAME_FRANCE = "silicon_france"                              # warehouse
SILICON_SERVICE_NAME_BRAZIL = "silicon_brazil"                              # warehouse
SILICON_SERVICE_NAME_MALAYSIA = "silicon_malaysia"                          # warehouse
WAFER_SERVICE_NAME_JAPAN = "wafer_japan"                                    # warehouse
WAFER_SERVICE_NAME_SOUTH_KOREA = "wafer_south_korea"                        # warehouse
BORON_SERVICE_NAME_TURKEY = "boron_turkey"                                  # warehouse
BORON_SERVICE_NAME_USA = "boron_usa"                                        # warehouse
BORON_SERVICE_NAME_KAZAKHSTAN = "boron_kazakhstan"                          # warehouse
BORON_SERVICE_NAME_CHILE = "boron_chile"                                    # warehouse
BORON_SERVICE_NAME_CHINA = "boron_china"                                    # warehouse
BORON_SERVICE_NAME_ARGENTINA = "boron_argentina"                            # warehouse
BORON_SERVICE_NAME_RUSSIA = "boron_russia"                                  # warehouse
BORON_SERVICE_NAME_BOLIVIA = "boron_bolivia"                                # warehouse
PHOSPHOR_SERVICE_NAME_MOROCCO = "phosphor_morocco"                          # warehouse
PHOSPHOR_SERVICE_NAME_CHINA = "phosphor_china"                              # warehouse
PHOSPHOR_SERVICE_NAME_USA = "phosphor_usa"                                  # warehouse
ALUMINUM_SERVICE_NAME_AUSTRALIA = "aluminum_australia"                      # warehouse
ALUMINUM_SERVICE_NAME_INDIA = "aluminum_india"                              # warehouse
ALUMINUM_SERVICE_NAME_BRAZIL = "aluminum_brazil"                            # warehouse
RESIST_SERVICE_NAME_USA = "resist_usa"                                      # warehouse
RESIST_SERVICE_NAME_BELGIUM = "resist_belgium"                              # warehouse
RESIST_SERVICE_NAME_AUSTRIA = "resist_austria"                              # warehouse
RESIST_SERVICE_NAME_INDIA = "resist_india"                                  # warehouse
RESIST_SERVICE_NAME_SWITZERLAND = "resist_switzerland"                      # warehouse
RESIST_SERVICE_NAME_CANADA = "resist_canada"                                # warehouse
PLASTIC_SERVICE_NAME_CHINA = "plastic_china"                                # warehouse
PLASTIC_SERVICE_NAME_INDIA = "plastic_india"                                # warehouse
CHEMICALS_SERVICE_NAME_USA = "chemicals_usa"                                # warehouse
CHEMICALS_SERVICE_NAME_CANADA = "chemicals_canada"                          # warehouse
COPPER_FRAME_SERVICE_NAME_USA = "copper_frame_usa"                          # warehouse
COPPER_FRAME_SERVICE_NAME_CHINA = "copper_frame_china"                      # warehouse
COPPER_FRAME_SERVICE_NAME_PERU = "copper_frame_peru"                        # warehouse
COPPER_FRAME_SERVICE_NAME_CHILE = "copper_frame_chile"                      # warehouse
CLEANING_SERVICE_NAME = "cleaning_human"                                    # human
FILM_DEPOSITION1_SERVICE_NAME = "film_deposition_machine1"                  # machine
FILM_DEPOSITION2_SERVICE_NAME = "film_deposition_machine2"                  # machine
RESIST_COATING1_SERVICE_NAME = "resist_coating_machine1"                    # machine
RESIST_COATING2_SERVICE_NAME = "resist_coating_machine2"                    # machine
EXPOSURE_SERVICE_NAME = "exposure_machine"                                  # machine
DEVELOPMENT1_SERVICE_NAME = "development_machine1"                          # machine
DEVELOPMENT2_SERVICE_NAME = "development_machine2"                          # machine
ETCHING1_SERVICE_NAME = "etching_machine1"                                  # machine
ETCHING2_SERVICE_NAME = "etching_machine2"                                  # machine
IMPURITIES_IMPLANTATION_SERVICE_NAME = "impurities_implantation_machine"    # machine
ACTIVATION_SERVICE_NAME = "activation_human"                                # human
RESIST_STRIPPING_SERVICE_NAME = "resist_stripping_machine"                  # machine
ASSEMBLY_SERVICE_NAME = "assembly_human"                                    # human
TESTING_SERVICE_NAME = "testing_human"                                      # human
PACKAGING_SERVICE_NAME = "packaging_human"                                  # human

# %% [markdown]
# We have different type of services:
#
# - generic breakable machines;
# - complex breakable machines;
# - warehouse machines;
# - human workers

# %%
def build_generic_breakable_service(service_name: str, action_name: str, broken_prob: float, broken_reward: float, action_reward: float):
    assert 0.0 <= broken_prob <= 1.0
    deterministic_prob = 1.0
    success_prob = deterministic_prob - broken_prob
    transitions = {
        "available": {
          action_name: ({"done": success_prob, "broken": broken_prob}, action_reward),
        },
        "broken": {
            f"check_{action_name}": ({"available": 1.0}, broken_reward),
        },
        "done": {
            f"check_{action_name}": ({"available": 1.0}, 0.0),
        }
    }
    final_states = {"available"}
    initial_state = "available"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

def build_complex_breakable_service(service_name: str, action_name: str, broken_prob: float, unemployable_prob: float, broken_reward: float, action_reward: float) -> Service:
    assert 0.0 <= broken_prob <= 1.0
    deterministic_prob = 1.0
    configure_success_prob = deterministic_prob - unemployable_prob
    op_success_prob = deterministic_prob - broken_prob
    transitions = {
        "ready": { # current state
            f"config_{action_name}": # action
                (
                    {
                        "configured": deterministic_prob # next state : prob
                    },
                    0.0
                ),
        },
        "configured": {
            f"checked_{action_name}":
                (
                    {
                    "executing": configure_success_prob,
                    "broken": unemployable_prob
                    } if unemployable_prob > 0.0 else {"executing": configure_success_prob},
                    0.0
                ),
        },
        "executing": {
            action_name: # operation
                (
                    {
                        "ready": op_success_prob,
                        "broken": broken_prob
                    } if broken_prob > 0.0 else {"ready": op_success_prob},
                    action_reward
                ),
        },
        "broken": {
            f"restore_{action_name}":
               (
                   {
                       "repairing": deterministic_prob
                   },
                   broken_reward
               ),
        },
        "repairing": {
            f"repaired_{action_name}":
                (
                    {
                        "ready": deterministic_prob
                    },
                    0.0
                ),
        },

    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

def build_generic_service_one_state(
    service_name: str,
    operation_names: Set[str],
    action_reward: float,
) -> Service:
    """Build the one state device."""
    transitions = {
        "ready": {
            operation_name: ({"ready": 1.0}, action_reward) for operation_name in operation_names
        },
    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

# %%
def design_service(name: str, action_reward: float) -> Service:
    """Build the design device."""
    return build_generic_service_one_state(
        name,
        {PICK_BUY_DESIGN},
        action_reward=action_reward
    )

service_design_usa = design_service(DESIGN_SERVICE_NAME_USA, USA_REWARD)
service_design_uk = design_service(DESIGN_SERVICE_NAME_UK, UK_REWARD)
service_design_china = design_service(DESIGN_SERVICE_NAME_CHINA, CHINA_REWARD)
service_design_taiwan = design_service(DESIGN_SERVICE_NAME_TAIWAN, TAIWAN_REWARD)
render_service(service_design_usa)
render_service(service_design_uk)
render_service(service_design_china)
render_service(service_design_taiwan)

# %%
def silicon_warehouse_service(name: str, action_reward) -> Service:
    """Build the silicon warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_SILICON},
        action_reward=action_reward
    )

service_silicon_china = silicon_warehouse_service(SILICON_SERVICE_NAME_CHINA, CHINA_REWARD)
service_silicon_russia = silicon_warehouse_service(SILICON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD)
service_silicon_norway = silicon_warehouse_service(SILICON_SERVICE_NAME_NORWAY, NORWAY_REWARD)
service_silicon_usa = silicon_warehouse_service(SILICON_SERVICE_NAME_USA, USA_REWARD)
service_silicon_brazil = silicon_warehouse_service(SILICON_SERVICE_NAME_BRAZIL, BRAZIL_REWARD)
service_silicon_france = silicon_warehouse_service(SILICON_SERVICE_NAME_FRANCE, FRANCE_REWARD)
service_silicon_malaysia = silicon_warehouse_service(SILICON_SERVICE_NAME_MALAYSIA, MALAYSIA_REWARD)
render_service(service_silicon_china)
render_service(service_silicon_russia)
render_service(service_silicon_norway)
render_service(service_silicon_usa)
render_service(service_silicon_brazil)
render_service(service_silicon_france)
render_service(service_silicon_malaysia)

# %%
def wafer_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the wafer warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_WAFER},
        action_reward=action_reward
    )

service_wafer_japan = wafer_warehouse_service(WAFER_SERVICE_NAME_JAPAN, JAPAN_REWARD)
service_wafer_south_korea = wafer_warehouse_service(WAFER_SERVICE_NAME_SOUTH_KOREA, SOUTH_KOREA)
render_service(service_wafer_japan)
render_service(service_wafer_south_korea)

# %%
def boron_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the boron warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_BORON},
        action_reward=action_reward
    )

service_boron_turkey = boron_warehouse_service(BORON_SERVICE_NAME_TURKEY, TURKEY_REWARD)
service_boron_usa = boron_warehouse_service(BORON_SERVICE_NAME_USA, USA_REWARD)
service_boron_kazakhstan = boron_warehouse_service(BORON_SERVICE_NAME_KAZAKHSTAN, KAZAKHSTAN_REWARD)
service_boron_chile = boron_warehouse_service(BORON_SERVICE_NAME_CHILE, CHILE_REWARD)
service_boron_china = boron_warehouse_service(BORON_SERVICE_NAME_CHINA, CHINA_REWARD)
service_boron_bolivia = boron_warehouse_service(BORON_SERVICE_NAME_BOLIVIA, BOLIVIA_REWARD)
service_boron_argentina = boron_warehouse_service(BORON_SERVICE_NAME_ARGENTINA, ARGENTINA_REWARD)
service_boron_russia = boron_warehouse_service(BORON_SERVICE_NAME_RUSSIA, RUSSIA_REWARD + WAR_REWARD)
render_service(service_boron_turkey)
render_service(service_boron_usa)
render_service(service_boron_kazakhstan)
render_service(service_boron_chile)
render_service(service_boron_china)
render_service(service_boron_bolivia)
render_service(service_boron_argentina)
render_service(service_boron_russia)

# %%
def phosphor_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the phosphor warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_PHOSPHOR},
        action_reward=action_reward
    )

service_phosphor_morocco = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_MOROCCO, MOROCCO_REWARD)
service_phosphor_china = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_CHINA, CHINA_REWARD)
service_phosphor_usa = phosphor_warehouse_service(PHOSPHOR_SERVICE_NAME_USA, USA_REWARD)
render_service(service_phosphor_morocco)
render_service(service_phosphor_china)
render_service(service_phosphor_usa)

# %%
def aluminum_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the aluminum warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_ALUMINUM},
        action_reward=action_reward
    )

service_aluminum_australia = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_AUSTRALIA, AUSTRALIA_REWARD)
service_aluminum_india = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_INDIA, INDIA_REWARD)
service_aluminum_brazil = aluminum_warehouse_service(ALUMINUM_SERVICE_NAME_BRAZIL, BRAZIL_REWARD)
render_service(service_aluminum_australia)
render_service(service_aluminum_india)
render_service(service_aluminum_brazil)

# %%
def resist_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the resist warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_RESIST},
        action_reward=action_reward
    )


service_resist_usa = resist_warehouse_service(RESIST_SERVICE_NAME_USA, USA_REWARD)
service_resist_belgium = resist_warehouse_service(RESIST_SERVICE_NAME_BELGIUM, BELGIUM_REWARD)
service_resist_austria = resist_warehouse_service(RESIST_SERVICE_NAME_AUSTRIA, AUSTRIA_REWARD)
service_resist_india = resist_warehouse_service(RESIST_SERVICE_NAME_INDIA, INDIA_REWARD)
service_resist_switzerland = resist_warehouse_service(RESIST_SERVICE_NAME_SWITZERLAND, SWITZERLAND_REWARD)
service_resist_canada = resist_warehouse_service(RESIST_SERVICE_NAME_CANADA, CANADA_REWARD)
render_service(service_resist_usa)
render_service(service_resist_belgium)
render_service(service_resist_austria)
render_service(service_resist_india)
render_service(service_resist_switzerland)
render_service(service_resist_canada)

# %%
def plastic_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the plastic warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_PLASTIC},
        action_reward=action_reward
    )


service_plastic_china = plastic_warehouse_service(PLASTIC_SERVICE_NAME_CHINA, CHINA_REWARD)
service_plastic_india = plastic_warehouse_service(PLASTIC_SERVICE_NAME_INDIA, INDIA_REWARD)
render_service(service_plastic_china)
render_service(service_plastic_india)

# %%
def chemicals_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the chemicals warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_CHEMICALS},
        action_reward=action_reward
    )


service_chemicals_usa = chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_USA, USA_REWARD)
service_chemicals_canada = chemicals_warehouse_service(CHEMICALS_SERVICE_NAME_CANADA, CANADA_REWARD)
render_service(service_chemicals_usa)
render_service(service_chemicals_canada)

# %%
def copper_frame_warehouse_service(name: str, action_reward: float) -> Service:
    """Build the copper frame warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_COPPER_FRAME},
        action_reward=action_reward
    )


service_copper_frame_usa = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_USA, USA_REWARD)
service_copper_frame_china = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHINA, CHINA_REWARD)
service_copper_frame_peru = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_PERU, PERU_REWARD)
service_copper_frame_chile = copper_frame_warehouse_service(COPPER_FRAME_SERVICE_NAME_CHILE, CHILE_REWARD)
render_service(service_copper_frame_usa)
render_service(service_copper_frame_china)
render_service(service_copper_frame_peru)
render_service(service_copper_frame_chile)

# %%
def cleaning_service(name: str = CLEANING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human cleaning device."""
    return build_generic_service_one_state(
        name,
        {CLEANING},
        action_reward=action_reward
    )


service_cleaning = cleaning_service()
render_service(service_cleaning)

# %%
def film_deposition_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                            action_reward: float) -> Service:
    """Build the film deposition device."""
    return build_complex_breakable_service(name, FILM_DEPOSITION, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_film_deposition1 = film_deposition_service(FILM_DEPOSITION1_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                   DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, DEFAULT_USA_REWARD)
service_film_deposition2 = film_deposition_service(FILM_DEPOSITION2_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_film_deposition1)
render_service(service_film_deposition2)

# %%
def resist_coating_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                           action_reward: float) -> Service:
    """Build the resist coating device."""
    return build_complex_breakable_service(name, RESIST_COATING, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_resist_coating1 = resist_coating_service(RESIST_COATING1_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                 DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, DEFAULT_USA_REWARD)
service_resist_coating2 = resist_coating_service(RESIST_COATING2_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                 DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_resist_coating1)
render_service(service_resist_coating2)

# %%
def exposure_service(name: str = EXPOSURE_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB,
                     broken_reward: float = DEFAULT_BROKEN_REWARD,
                     action_reward: float = DEFAULT_USA_REWARD) -> Service:
    """Build the exposure device."""
    return build_generic_breakable_service(name, EXPOSURE, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_exposure = exposure_service()
render_service(service_exposure)

# %%
def development_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                        action_reward: float) -> Service:
    """Build the development device."""
    return build_complex_breakable_service(name, DEVELOPMENT, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_development1 = development_service(DEVELOPMENT1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB,
                                           DEFAULT_BROKEN_REWARD, DEFAULT_USA_REWARD)
service_development2 = development_service(DEVELOPMENT2_SERVICE_NAME, BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_development1)
render_service(service_development2)

# %%
def etching_service(name: str, broken_prob: float, broken_reward: float, action_reward: float) -> Service:
    """Build the etching device."""
    return build_generic_breakable_service(name, ETCHING, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_etching1 = etching_service(ETCHING1_SERVICE_NAME, DEFAULT_BROKEN_PROB, DEFAULT_BROKEN_REWARD,
                                   DEFAULT_USA_REWARD)
service_etching2 = etching_service(ETCHING2_SERVICE_NAME, BROKEN_PROB, DEFAULT_BROKEN_REWARD, HIGH_USA_REWARD)
render_service(service_etching1)
render_service(service_etching2)

# %%
def impurities_implantation_service(name: str, broken_prob: float, unemployable_prob: float, broken_reward: float,
                                    action_reward: float) -> Service:
    """Build the impurities implantation device."""
    return build_complex_breakable_service(name, IMPURITIES_IMPLANTATION, broken_prob=broken_prob,
                                           unemployable_prob=unemployable_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_impurities_implantation = impurities_implantation_service(IMPURITIES_IMPLANTATION_SERVICE_NAME,
                                                                   DEFAULT_BROKEN_PROB, DEFAULT_UNEMPLOYABLE_PROB,
                                                                   DEFAULT_BROKEN_REWARD, DEFAULT_USA_REWARD)
render_service(service_impurities_implantation)

# %%
def activation_service(name: str = ACTIVATION_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human activation device."""
    return build_generic_service_one_state(
        name,
        {ACTIVATION},
        action_reward=action_reward
    )


service_activation = activation_service()
render_service(service_activation)

# %%
def resist_stripping_service(name: str, broken_prob: float, broken_reward: float, action_reward: float) -> Service:
    """Build the resist stripping device."""
    return build_generic_breakable_service(name, RESIST_STRIPPING, broken_prob=broken_prob, broken_reward=broken_reward,
                                           action_reward=action_reward)


service_resist_stripping = resist_stripping_service(RESIST_STRIPPING_SERVICE_NAME, DEFAULT_BROKEN_PROB,
                                                     DEFAULT_BROKEN_REWARD, DEFAULT_USA_REWARD)

render_service(service_resist_stripping)

# %%
def assembly_service(name: str = ASSEMBLY_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human assembly device."""
    return build_generic_service_one_state(
        name,
        {ASSEMBLY},
        action_reward=action_reward
    )


service_assembly = assembly_service()
render_service(service_assembly)

# %%
def testing_service(name: str = TESTING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human testing device."""
    return build_generic_service_one_state(
        name,
        {TESTING},
        action_reward=action_reward
    )


service_testing = testing_service()
render_service(service_testing)

# %%
def packaging_service(name: str = PACKAGING_SERVICE_NAME, action_reward: float = USA_REWARD) -> Service:
    """Build the human packaging device."""
    return build_generic_service_one_state(
        name,
        {PACKAGING},
        action_reward=action_reward
    )


service_packaging = packaging_service()
render_service(service_packaging)

# %% [markdown]
# # First Phase - Raw materials and design assortment
# ## Target Specification
# The target specification of the first phase is defined as follows:

# %%
def target_service():
    """Build the target service."""
    transition_function = {
       "s0": {
            "pick_buy_design": ("s1", 1.0, 0),
        },
        "s1": {"pick_silicon": ("s2", 1.0, 0),
        },
        "s2": {"pick_wafer": ("s3", 1.0, 0),},
        "s3": {"pick_boron": ("s4", 1.0, 0), },
        "s4": {"pick_phosphor": ("s5", 1.0, 0), },
        "s5": {"pick_aluminum": ("s6", 1.0, 0), },
        "s6": {"pick_resist": ("s7", 1.0, 0), },
        "s7": {"pick_plastic": ("s8", 1.0, 0), },
        "s8": {"pick_chemicals": ("s9", 1.0, 0), },
        "s9": {"pick_copper_frame": ("s0", 1.0, 0), },
    }

    initial_state = "s0"
    final_states = {"s0"}

    return build_target_from_transitions(
        transition_function, initial_state, final_states
    )

target = target_service()
render_target(target)

# %% [markdown]
# ## Composition MDP
# The Composition MDP is constructed in this way:

# %%
all_services = [
    # 0
    service_design_usa,
    # 1
    service_design_uk,
    # 2
    service_design_china,
    # 3
    service_design_taiwan,
    # 4
    service_silicon_china,
    # 5
    service_silicon_russia,
    # 6
    service_silicon_norway,
    # 7
    service_silicon_usa,
    # 8
    service_silicon_brazil,
    # 9
    service_silicon_france,
    # 10
    service_silicon_malaysia,
    # 11
    service_wafer_japan,
    # 12
    service_wafer_south_korea,
    # 13
    service_boron_turkey,
    # 14
    service_boron_usa,
    # 15
    service_boron_kazakhstan,
    # 16
    service_boron_chile,
    # 17
    service_boron_china,
    # 18
    service_boron_bolivia,
    # 19
    service_boron_argentina,
    # 20
    service_boron_russia,
    # 21
    service_phosphor_morocco,
    # 22
    service_phosphor_china,
    # 23
    service_phosphor_usa,
    # 24
    service_aluminum_brazil,
    # 25
    service_aluminum_india,
    # 26
    service_aluminum_australia,
    # 27
    service_resist_switzerland,
    # 28
    service_resist_usa,
    # 29
    service_resist_austria,
    # 30
    service_resist_belgium,
    # 31
    service_resist_canada,
    # 32
    service_resist_india,
    # 33
    service_plastic_india,
    # 34
    service_plastic_china,
    # 35
    service_chemicals_usa,
    # 36
    service_chemicals_canada,
    # 37
    service_copper_frame_usa,
    # 38
    service_copper_frame_chile,
    # 39
    service_copper_frame_peru,
    # 40
    service_copper_frame_china
]
mdp = composition_mdp(target, *all_services, gamma=0.9)
render_composition_mdp(mdp)
print("Number of states: ", len(mdp.all_states))
# Out:
# Number of states:  11

# %% [markdown]
# # Optimal policy
# Calculation of optimal policy:

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
value_function = opn.get_value_func_dict(opt_policy)
q_value_function = opn.get_act_value_func_dict(opt_policy)

# remove '0' state to sort output
opt_policy.policy_data.pop(0, None)
value_function.pop(0, None)
_ = q_value_function.pop(0, None)

# %%
print_policy_data(opt_policy)
# Out:
# Policy:
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's0', 'pick_buy_design'),	Action=0
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's1', 'pick_silicon'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's2', 'pick_wafer'),	Action=11
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's3', 'pick_boron'),	Action=14
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's4', 'pick_phosphor'),	Action=23
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's5', 'pick_aluminum'),	Action=24
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's6', 'pick_resist'),	Action=31
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's7', 'pick_plastic'),	Action=34
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's8', 'pick_chemicals'),	Action=36
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 's9', 'pick_copper_frame'),	Action=37

# %% [markdown]
# # Value Function
# Calculation of Value Function:

# %%
print_value_function(value_function)
# Out:
# Value function:
# State=0,	value=-9.755805719030063
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 2, 'pick_silicon'),	value=-9.821982369172916
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 0, 'pick_buy_design'),	value=-10.839784132255625
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 4, 'pick_boron'),	value=-9.780225147127059
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 5, 'pick_phosphor'),	value=-9.755805719030063
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 3, 'pick_wafer'),	value=-9.802202632414351

# %%
print_q_value_function(q_value_function)
# Out:
# Q-value function:
# State=0:
# 	Action=initial,	Value=-9.755805719030063
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 0, 'pick_buy_design'):
# 	Action=0,	Value=-10.839784132255625
# 	Action=1,	Value=-15.639784132255624
# 	Action=2,	Value=-20.539784132255626
# 	Action=3,	Value=-21.039784132255626
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 2, 'pick_silicon'):
# 	Action=4,	Value=-9.821982369172916
# 	Action=5,	Value=-20.521982369172918
# 	Action=6,	Value=-20.941982369172916
# 	Action=7,	Value=-15.981982369172917
# 	Action=8,	Value=-10.821982369172916
# 	Action=9,	Value=-15.521982369172918
# 	Action=10,	Value=-16.421982369172916
# 	Action=11,	Value=-23.55198236917292
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 3, 'pick_wafer'):
# 	Action=12,	Value=-9.802202632414353
# 	Action=13,	Value=-18.90220263241435
# 	Action=14,	Value=-19.502202632414352
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 4, 'pick_boron'):
# 	Action=15,	Value=-9.780225147127057
# 	Action=16,	Value=-20.480225147127058
# 	Action=17,	Value=-10.780225147127057
# 	Action=18,	Value=-16.580225147127056
# 	Action=19,	Value=-19.180225147127057
# 	Action=20,	Value=-20.900225147127056
# 	Action=21,	Value=-17.33022514712706
# 	Action=22,	Value=-15.580225147127056
# 	Action=23,	Value=-18.94022514712706
#
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready'), 5, 'pick_phosphor'):
# 	Action=24,	Value=-9.755805719030063
# 	Action=25,	Value=-20.45580571903006
# 	Action=26,	Value=-16.655805719030063
# 	Action=27,	Value=-10.755805719030063

# %% [markdown]
# From the calculation of the optimal policy we observe that:
# - the planner preferred using service `service_design_usa` (service `0`) because it was more convenient choose the service located in usa than the services of other countries;
# - the planner preferred using service `service_silicon_warehouse` (service `4`) because it was more convenient pick the silicon from the warehouse instead of picking it from other countries;
# - the planner preferred using service `service_wafer_warehouse` (service `12`) because it was more convenient pick the wafer from the warehouse instead of picking it from other countries;
# - the planner preferred using service `service_boron_warehouse` (service `15`) because it was more convenient pick the boron from the warehouse instead of picking it from other countries;
# - the planner preferred using service `service_phosphor_warehouse` (service `24`) because it was more convenient pick the phosphor from the warehouse instead of picking it from other countries.

# %% [markdown]
# # Second phase - Manufacturing Process
# ## Target Specification
# The target specification of the second phase is structured as follows:

# %%
def target_service():
    """Build the target service."""
    transition_function = {
        "s0": {"cleaning": ("s1", 1.0, 0), },
        "s1": {"CONFIG[film_deposition]": ("s2", 1.0, 0), },
        "s2": {"CHECKED[film_deposition]": ("s3", 1.0, 0), },
        "s3": {"film_deposition": ("s4", 1.0, 0), },
        "s4": {"CONFIG[resist_coating]": ("s5", 1.0, 0), },
        "s5": {"CHECKED[resist_coating]": ("s6", 1.0, 0), },
        "s6": {"resist_coating": ("s7", 1.0, 0), },
        "s7": {"exposure": ("s8", 1.0, 0), },
        "s8": {"check_exposure": ("s9", 1.0, 0), },
        "s9": {"CONFIG[development]": ("s10", 1.0, 0), },
        "s10": {"CHECKED[development]": ("s11", 1.0, 0), },
        "s11": {"development": ("s12", 1.0, 0), },
        "s12": {"etching": ("s13", 1.0, 0), },
        "s13": {"check_etching": ("s14", 1.0, 0), },
        "s14": {"CONFIG[impurities_implantation]": ("s15", 1.0, 0), },
        "s15": {"CHECKED[impurities_implantation]": ("s16", 1.0, 0), },
        "s16": {"impurities_implantation": ("s17", 1.0, 0), },
        "s17": {"activation": ("s18", 1.0, 0), },
        "s18": {"resist_stripping": ("s19", 1.0, 0), },
        "s19": {"check_resist_stripping": ("s20", 1.0, 0), },
        "s20": {"assembly": ("s21", 1.0, 0), },
        "s21": {"testing": ("s22", 1.0, 0), },
        "s22": {"packaging": ("s0", 1.0, 0), }
 }

    initial_state = "s0"
    final_states = {"s0"}

    return build_target_from_transitions(
        transition_function, initial_state, final_states
    )

target = target_service()
render_target(target)

# %%
all_services = [
    # 0
    service_cleaning,
    # 1
    service_film_deposition1,
    # 2
    service_film_deposition2,
    # 3
    service_resist_coating1,
    # 4
    service_resist_coating2,
    # 5
    service_exposure,
    # 6
    service_development1,
    # 7
    service_development2,
    # 8
    service_etching1,
    # 9
    service_etching2,
    # 10
    service_impurities_implantation,
    # 11
    service_activation,
    # 12
    service_resist_stripping,
    # 13
    service_assembly,
    # 14
    service_testing,
    # 15
    service_packaging
]
mdp = composition_mdp(target, *all_services, gamma=0.9)
#render_composition_mdp2(mdp)
print("Number of states: ", len(mdp.all_states))
# Out:
# Number of states:  1825

# %% [markdown]
# # Optimal policy
# Calculation of optimal policy:

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
value_function = opn.get_value_func_dict(opt_policy)
q_value_function = opn.get_act_value_func_dict(opt_policy)

# %%
print_policy_data(opt_policy)
# Out:
# Policy:
# State=0,	Action=initial
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 0, 'cleaning'),	Action=0
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=2
# State=(('ready', 'configured', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'ready', 'configured', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'executing', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'executing', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=3
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=3
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=3
# State=(('ready', 'ready', 'ready', 'configured', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=3
# State=(('ready', 'ready', 'ready', 'ready', 'configured', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=4
# State=(('ready', 'broken', 'ready', 'configured', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=3
# State=(('ready', 'broken', 'ready', 'ready', 'configured', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=4
# State=(('ready', 'ready', 'broken', 'configured', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=3
# State=(('ready', 'ready', 'broken', 'ready', 'configured', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 6, 'checked_resist_coating'),	Action=4
# State=(('ready', 'ready', 'ready', 'executing', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=3
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'executing', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=4
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'executing', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=3
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'executing', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=4
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'executing', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=3
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'ready', 'executing', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=4
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 7, 'resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 8, 'exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'done', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'broken', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 9, 'check_exposure'),	Action=5
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 10, 'config_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'configured', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 11, 'checked_development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'executing', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=6
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 12, 'development'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 13, 'etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'done', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'broken', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=8
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'done', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'broken', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 14, 'check_etching'),	Action=7
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 15, 'config_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'configured', 'ready', 'available', 'ready', 'ready', 'ready'), 16, 'checked_impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'ready', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# State=(('ready', 'broken', 'ready', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'executing', 'ready', 'available', 'ready', 'ready', 'ready'), 17, 'impurities_implantation'),	Action=9
# ...
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=1
# State=(('ready', 'broken', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'ready', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'ready', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'ready', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 2, 'config_film_deposition'),	Action=undefined
# State=(('ready', 'configured', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'ready', 'configured', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'configured', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'ready', 'configured', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'configured', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'ready', 'configured', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'configured', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'ready', 'configured', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'broken', 'configured', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'broken', 'configured', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'broken', 'configured', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'broken', 'configured', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=2
# State=(('ready', 'configured', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'configured', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'configured', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'configured', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 3, 'checked_film_deposition'),	Action=1
# State=(('ready', 'executing', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'executing', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'executing', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'executing', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'executing', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'executing', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'executing', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'ready', 'executing', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'executing', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'executing', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'executing', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'broken', 'executing', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=2
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=undefined
# State=(('ready', 'executing', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'executing', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'executing', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'executing', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 4, 'film_deposition'),	Action=1
# State=(('ready', 'ready', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'ready', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'ready', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'ready', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'ready', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined
# State=(('ready', 'broken', 'broken', 'broken', 'broken', 'available', 'broken', 'available', 'available', 'broken', 'ready', 'available', 'ready', 'ready', 'ready'), 5, 'config_resist_coating'),	Action=undefined

# %% [markdown]
# # Value Function
# Calculation of Value Function:

# %%
print_value_function(value_function)

# %%
print_q_value_function(q_value_function)
