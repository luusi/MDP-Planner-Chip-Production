# %%
from typing import Set

# Python imports, put at the top for simplicity
from mdp_dp_rl.algorithms.dp.dp_analytic import DPAnalytic
from docs.notebooks.utils import render_service, render_target, render_composition_mdp, print_policy_data, print_value_function, print_q_value_function
from stochastic_service_composition.composition_mdp import composition_mdp
from stochastic_service_composition.services import build_service_from_transitions, Service
from stochastic_service_composition.target import build_target_from_transitions

# %% [markdown]
# ## Use case for "Stochastic Service Composition with Industrial APIs" - Chip Production.
#
# In this notebook, we present the implementation of the use case for "Stochastic Service Composition with Industrial APIs" about chip production.

# %% [markdown]
# # Available Services
#
# In the following we provide definitions about available services:

# %%
# all the atomic actions for the task
PICK_BUY_DESIGN = "pick/buy_design"
PICK_SILICON = "pick_silicon"
PICK_WAFER = "pick_wafer"
PICK_BORON = "pick_boron"
PICK_PHOSPHOR = "pick_phosphor"
FILM_DEPOSITION = "film_deposition"
RESIST_COATING = "resist_coating"
EXPOSURE = "exposure"
DEVELOPMENT = "development"
ETCHING = "etching"
IMPURITIES_IMPLANTATION = "impurities_implantation"
ACTIVATION = "activation"
RESIST_STRIPPING = "resist_stripping"
ASSEMBLY = "assembly"
PACKAGING = "packaging"

# service names
DESIGN_SERVICE_NAME = "design_human"                                        # human
SILICON_WAREHOUSE_SERVICE_NAME = "silicon_warehouse"                        # warehouse
WAFER_WAREHOUSE_SERVICE_NAME = "wafer_warehouse"                            # warehouse
BORON_WAREHOUSE_SERVICE_NAME = "boron_warehouse"                            # warehouse
PHOSPHOR_WAREHOUSE_SERVICE_NAME = "phosphor_warehouse"                      # warehouse
SILICON_SERVICE_NAME = "silicon_human"                                      # human
WAFER_SERVICE_NAME = "wafer_human"                                          # human
BORON_SERVICE_NAME = "boron_human"                                          # human
PHOSPHOR_SERVICE_NAME = "phosphor_human"                                    # human
FILM_DEPOSITION_SERVICE_NAME = "film_deposition_machine"                    # machine
RESIST_COATING_SERVICE_NAME = "resist_coating_machine"                      # machine
EXPOSURE_SERVICE_NAME = "exposure_machine"                                  # machine
DEVELOPMENT_SERVICE_NAME = "development_machine"                            # machine
ETCHING_SERVICE_NAME = "etching_machine"                                    # machine
IMPURITIES_IMPLANTATION_SERVICE_NAME = "impurities_implantation_machine"    # machine
ACTIVATION_SERVICE_NAME = "activation_machine"                              # machine
RESIST_STRIPPING_SERVICE_NAME = "resist_stripping_machine"                  # machine
ASSEMBLY_SERVICE_NAME = "assembly_machine"                                  # machine
PACKAGING_SERVICE_NAME = "packaging_machine"                                # machine

# %%
DEFAULT_REWARD = -1.0
DEFAULT_BROKEN_REWARD = -10.0

LOW_PROB = 0.05
DEFAULT_BROKEN_PROB = LOW_PROB
DEFAULT_UNEMPLOYABLE_PROB = LOW_PROB

#This is a preliminary function
def build_generic_breakable_service(service_name: str, action_name: str, broken_prob: float, unemployable_prob: float, broken_reward: float, action_reward: float) -> Service:
    assert 0.0 <= broken_prob <= 1.0
    deterministic_prob = 1.0
    configure_success_prob = deterministic_prob - unemployable_prob
    op_success_prob = deterministic_prob - broken_prob
    transitions = {
        "ready": { # current state
            f"CONFIG[{service_name}]": # action
                (
                    {
                        "configured": deterministic_prob # next state : prob
                    },
                    action_reward
                ),
        },
        "configured": {
            f"CHECKED[{service_name}]":
                (
                    {
                    "executing": configure_success_prob,
                    "broken": unemployable_prob
                    } if unemployable_prob > 0.0 else {"executing": configure_success_prob},
                    action_reward
                ),
        },
        "executing": {
            action_name: # operation
                (
                    {
                        "ready": op_success_prob,
                        "broken": broken_prob
                    } if broken_prob > 0.0 else {"ready": op_success_prob},
                    action_reward
                ),
        },
        "broken": {
            f"RESTORE[{service_name}]":
               (
                   {
                       "repairing": deterministic_prob
                   },
                   broken_reward
               ),
        },
        "repairing": {
            f"REPAIRED[{service_name}]":
                (
                    {
                        "ready": deterministic_prob
                    },
                    action_reward
                ),
        },

    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore


def build_generic_service_one_state(
    service_name: str,
    operation_names: Set[str],
    action_reward: float,
) -> Service:
    """Build the one state device."""
    transitions = {
        "ready": {
            operation_name: ({"ready": 1.0}, action_reward) for operation_name in operation_names
        },
    }
    final_states = {"ready"}
    initial_state = "ready"
    return build_service_from_transitions(transitions, initial_state, final_states)  # type: ignore

# %%
def design_service(name: str = DESIGN_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the design device."""
    return build_generic_service_one_state(
        name,
        {PICK_BUY_DESIGN},
        action_reward=action_reward
    )

service_design_usa = design_service(DESIGN_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_design_uk = design_service(DESIGN_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_design_china = design_service(DESIGN_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_design_taiwan = design_service(DESIGN_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_design_usa)
render_service(service_design_uk)
render_service(service_design_china)
render_service(service_design_taiwan)

# %%
def silicon_warehouse_service(name: str = SILICON_WAREHOUSE_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the silicon warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_SILICON},
        action_reward=action_reward
    )

service_silicon_warehouse = silicon_warehouse_service(SILICON_WAREHOUSE_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_silicon_warehouse)

# %%
def silicon_service(name: str = SILICON_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the silicon device."""
    return build_generic_service_one_state(
        name,
        {PICK_SILICON},
        action_reward=action_reward
    )

service_silicon_china = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_russia = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_norway = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_usa = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_brazil = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_france = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_silicon_malaysia = silicon_service(SILICON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_silicon_china)
render_service(service_silicon_russia)
render_service(service_silicon_norway)
render_service(service_silicon_usa)
render_service(service_silicon_brazil)
render_service(service_silicon_france)
render_service(service_silicon_malaysia)

# %%
def wafer_warehouse_service(name: str = WAFER_WAREHOUSE_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the wafer warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_WAFER},
        action_reward=action_reward
    )

service_wafer_warehouse = wafer_warehouse_service(WAFER_WAREHOUSE_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_wafer_warehouse)

# %%
def wafer_service(name: str = WAFER_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the wafer device."""
    return build_generic_service_one_state(
        name,
        {PICK_WAFER},
        action_reward=action_reward
    )

service_wafer_japan = wafer_service(WAFER_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_wafer_south_korea = wafer_service(WAFER_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_wafer_japan)
render_service(service_wafer_south_korea)

# %%
def boron_warehouse_service(name: str = BORON_WAREHOUSE_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the boron warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_BORON},
        action_reward=action_reward
    )

service_boron_warehouse = boron_warehouse_service(BORON_WAREHOUSE_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_boron_warehouse)

# %%
def boron_service(name: str = BORON_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the boron device."""
    return build_generic_service_one_state(
        name,
        {PICK_BORON},
        action_reward=action_reward
    )

service_boron_turkey = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_usa = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_kazakhstan = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_chile = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_china = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_bolivia = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_argentina = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_boron_russia = boron_service(BORON_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_boron_turkey)
render_service(service_boron_usa)
render_service(service_boron_kazakhstan)
render_service(service_boron_chile)
render_service(service_boron_china)
render_service(service_boron_bolivia)
render_service(service_boron_argentina)
render_service(service_boron_russia)

# %%
def phosphor_warehouse_service(name: str = PHOSPHOR_WAREHOUSE_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the phosphor warehouse device."""
    return build_generic_service_one_state(
        name,
        {PICK_PHOSPHOR},
        action_reward=action_reward
    )

service_phosphor_warehouse = phosphor_warehouse_service(PHOSPHOR_WAREHOUSE_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_phosphor_warehouse)

# %%
def phosphor_service(name: str = PHOSPHOR_SERVICE_NAME, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the phosphor device."""
    return build_generic_service_one_state(
        name,
        {PICK_PHOSPHOR},
        action_reward=action_reward
    )

service_phosphor_morocco = phosphor_service(PHOSPHOR_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_phosphor_china = phosphor_service(PHOSPHOR_SERVICE_NAME, action_reward = DEFAULT_REWARD)
service_phosphor_usa = phosphor_service(PHOSPHOR_SERVICE_NAME, action_reward = DEFAULT_REWARD)
render_service(service_phosphor_morocco)
render_service(service_phosphor_china)
render_service(service_phosphor_usa)

# %%
def film_deposition_service(name: str = FILM_DEPOSITION_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the film deposition device."""
    return build_generic_breakable_service(name, FILM_DEPOSITION, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_film_deposition=film_deposition_service()
render_service(service_film_deposition)

# %%
def resist_coating_service(name: str = RESIST_COATING_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the resist coating device."""
    return build_generic_breakable_service(name, RESIST_COATING, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_resist_coating=resist_coating_service()
render_service(service_resist_coating)

# %%
def exposure_service(name: str = EXPOSURE_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the exposure coating device."""
    return build_generic_breakable_service(name, EXPOSURE, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_exposure=exposure_service()
render_service(service_exposure)

# %%
def development_service(name: str = DEVELOPMENT_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the development device."""
    return build_generic_breakable_service(name, DEVELOPMENT, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_development=development_service()
render_service(service_development)

# %%
def etching_service(name: str = ETCHING_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the etching device."""
    return build_generic_breakable_service(name, ETCHING, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_etching=etching_service()
render_service(service_etching)

# %%
def impurities_implantation_service(name: str = IMPURITIES_IMPLANTATION_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the impurities implantation device."""
    return build_generic_breakable_service(name, IMPURITIES_IMPLANTATION, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_impurities_implantation=impurities_implantation_service()
render_service(service_impurities_implantation)

# %%
def activation_service(name: str = ACTIVATION_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the activation device."""
    return build_generic_breakable_service(name, ACTIVATION, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_activation=activation_service()
render_service(service_activation)

# %%
def resist_stripping_service(name: str = RESIST_STRIPPING_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the resist stripping device."""
    return build_generic_breakable_service(name, RESIST_STRIPPING, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_resist_stripping=resist_stripping_service()
render_service(service_resist_stripping)

# %%
def assembly_service(name: str = ASSEMBLY_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the assembly device."""
    return build_generic_breakable_service(name, ASSEMBLY, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_assembly=assembly_service()
render_service(service_assembly)

# %%
def packaging_service(name: str = PACKAGING_SERVICE_NAME, broken_prob: float = DEFAULT_BROKEN_PROB, unemployable_prob: float = DEFAULT_UNEMPLOYABLE_PROB, broken_reward: float = DEFAULT_BROKEN_REWARD, action_reward: float = DEFAULT_REWARD) -> Service:
    """Build the packaging device."""
    return build_generic_breakable_service(name, PACKAGING, broken_prob=broken_prob, unemployable_prob=unemployable_prob, broken_reward=broken_reward, action_reward=action_reward)
service_packaging=packaging_service()
render_service(service_packaging)

# %% [markdown]
# # Target Specification
# The target specification is defined as follows:

# %%
def target_service():
    """Build the target service."""
    transition_function = {
        "s0": {
            "pick/buy_design": ("s1", 1.0, 0),
        },
        "s1": {"pick_silicon": ("s2", 1.0, 0),
        },
        "s2": {"pick_wafer": ("s3", 1.0, 0),},
        "s3": {"pick_boron": ("s4", 1.0, 0), },
        "s4": {"pick_phosphor": ("s5", 1.0, 0), },
        "s5": {"CONFIG[film_depositing_machine]": ("s6", 1.0, 0), },
        "s6": {"CHECKED[film_depositing_machine]": ("s7", 1.0, 0), },
        "s7": {"film_depositing": ("s8", 1.0, 0), },
        "s8": {"CONFIG[resist_coating_machine]": ("s9", 1.0, 0), },
        "s9": {"CHECKED[resist_coating_machine]": ("s10", 1.0, 0), },
        "s10": {"resist_coating": ("s11", 1.0, 0), },
        "s11": {"CONFIG[exposure_machine]": ("s12", 1.0, 0), },
        "s12": {"CHECKED[exposure_machine]": ("s13", 1.0, 0), },
        "s13": {"exposure": ("s14", 1.0, 0), },
        "s14": {"CONFIG[development_machine]": ("s15", 1.0, 0), },
        "s15": {"CHECKED[development_machine]": ("s16", 1.0, 0), },
        "s16": {"development": ("s17", 1.0, 0), },
        "s17": {"CONFIG[etching_machine]": ("s18", 1.0, 0), },
        "s18": {"CHECKED[etching_machine]": ("s19", 1.0, 0), },
        "s19": {"etching": ("s20", 1.0, 0), },
        "s20": {"CONFIG[impurities_implantation_machine]": ("s21", 1.0, 0), },
        "s21": {"CHECKED[impurities_implantation_machine]": ("s22", 1.0, 0), },
        "s22": {"impurities_implantation": ("s23", 1.0, 0), },
        "s23": {"CONFIG[activation_machine]": ("s24", 1.0, 0), },
        "s24": {"CHECKED[activation_machine]": ("s25", 1.0, 0), },
        "s25": {"activation": ("s26", 1.0, 0), },
        "s26": {"CONFIG[resist_stripping_machine]": ("s27", 1.0, 0), },
        "s27": {"CHECKED[resist_stripping_machine]": ("s28", 1.0, 0), },
        "s28": {"resist_stripping": ("s29", 1.0, 0), },
        "s29": {"CONFIG[assembly_machine]": ("s30", 1.0, 0), },
        "s30": {"CHECKED[assembly_machine]": ("s31", 1.0, 0), },
        "s31": {"assembly": ("s32", 1.0, 0), },
        "s32": {"CONFIG[packaging_machine]": ("s33", 1.0, 0), },
        "s33": {"CHECKED[packaging_machine]": ("s34", 1.0, 0), },
        "s34": {"packaging": ("s0", 1.0, 0), },
    }

    initial_state = "s0"
    final_states = {"s0"}

    return build_target_from_transitions(
        transition_function, initial_state, final_states
    )

target = target_service()
render_target(target)

# %% [markdown]
# ## Composition MDP
# The Composition MDP is constructed in this way:

# %%
all_services = [
    service_design_usa,
    service_design_uk,
    service_design_china,
    service_design_taiwan,
    service_silicon_warehouse,
    service_silicon_china,
    service_silicon_russia,
    service_silicon_norway,
    service_silicon_usa,
    service_silicon_brazil,
    service_silicon_france,
    service_silicon_malaysia,
    service_wafer_warehouse,
    service_wafer_japan,
    service_wafer_south_korea,
    service_boron_warehouse,
    service_boron_turkey,
    service_boron_usa,
    service_boron_kazakhstan,
    service_boron_chile,
    service_boron_china,
    service_boron_bolivia,
    service_boron_argentina,
    service_boron_russia,
    service_phosphor_warehouse,
    service_phosphor_morocco,
    service_phosphor_china,
    service_phosphor_usa,
    service_film_deposition,
    service_resist_coating,
    service_exposure,
    service_development,
    service_etching,
    service_impurities_implantation,
    service_activation,
    service_resist_stripping,
    service_assembly,
    service_packaging
    ]
mdp = composition_mdp(target, *all_services, gamma=0.9)
render_composition_mdp(mdp)

# %% [markdown]
# # Optimal policy
# Calculation of optimal policy:

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
value_function = opn.get_value_func_dict(opt_policy)
q_value_function = opn.get_act_value_func_dict(opt_policy)

# remove '0' state to sort output
opt_policy.policy_data.pop(0, None)
value_function.pop(0, None)
_ = q_value_function.pop(0, None)

# %%
print_policy_data(opt_policy)

# %% [markdown]
# # Value Function
# Calculation of Value Function:

# %%
print_value_function(value_function)

# %%
print_q_value_function(q_value_function)
